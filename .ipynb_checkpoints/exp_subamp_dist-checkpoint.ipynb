# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import h5py
import os
import time

from util import *
from data_loader import * 
import scdd as sd
import dist_deconv_1d as dd1d

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_13m = load_10x_1_3mil()
sc.pp.filter_genes(data_13m,min_counts=10*data_13m.shape[0])

# %%
Nc,G = data_13m.shape
Nr = data_13m.X.sum()/Nc
B = Nc*Nr
Nr_bar = Nr/G
print(B,Nc,Nr,Nr_bar)
# Out:
# 1650557568.0 1306127 1263.703734782299 17.551440760865265

# %%
B_sub_list = [int(B/10000),int(B/5000),int(B/2000),int(B/1000)]
param=[]
for B_sub in B_sub_list:
    for Nr_bar in [0.5,1,2,3,4,5,8,10]:
        param.append((B_sub,Nr_bar,Nr_bar*G,int(B_sub/Nr_bar/G)))

# %%
data_subsamp = {}
for i in range(len(param)):
    _,Nr_bar_,Nr_,Nc_ = param[i]
    data_subsamp[param[i]]=sd.subsamp_anndata(data_13m,Nr_,Nc_)
# Out:
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (4584, 72)
# #time sub-sample cells: 0.1636s
# #time sub-sample counts: 4.7166s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (2292, 72)
# #time sub-sample cells: 0.1111s
# #time sub-sample counts: 2.6026s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (1146, 72)
# #time sub-sample cells: 0.1196s
# #time sub-sample counts: 1.3612s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (764, 72)
# #time sub-sample cells: 0.0926s
# #time sub-sample counts: 0.8427s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (573, 72)
# #time sub-sample cells: 0.1039s
# #time sub-sample counts: 0.6670s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (458, 72)
# #time sub-sample cells: 0.1033s
# #time sub-sample counts: 0.6096s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (286, 72)
# #time sub-sample cells: 0.1192s
# #time sub-sample counts: 0.4475s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (229, 72)
# #time sub-sample cells: 0.1165s
# #time sub-sample counts: 0.4067s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (9169, 72)
# #time sub-sample cells: 0.1336s
# ## 5000 cells processed
# #time sub-sample counts: 8.9162s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (4584, 72)
# #time sub-sample cells: 0.1209s
# #time sub-sample counts: 4.7652s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (2292, 72)
# #time sub-sample cells: 0.1293s
# #time sub-sample counts: 2.4838s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (1528, 72)
# #time sub-sample cells: 0.1060s
# #time sub-sample counts: 1.6939s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (1146, 72)
# #time sub-sample cells: 0.1080s
# #time sub-sample counts: 1.2346s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (916, 72)
# #time sub-sample cells: 0.1324s
# #time sub-sample counts: 0.9871s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (573, 72)
# #time sub-sample cells: 0.1002s
# #time sub-sample counts: 0.7246s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (458, 72)
# #time sub-sample cells: 0.0927s
# #time sub-sample counts: 0.5676s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (22924, 72)
# #time sub-sample cells: 0.1682s
# ## 5000 cells processed
# ## 10000 cells processed
# ## 15000 cells processed
# ## 20000 cells processed
# #time sub-sample counts: 21.7111s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (11462, 72)
# #time sub-sample cells: 0.1321s
# ## 5000 cells processed
# ## 10000 cells processed
# #time sub-sample counts: 10.7652s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (5731, 72)
# #time sub-sample cells: 0.1177s
# ## 5000 cells processed
# #time sub-sample counts: 5.6235s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (3820, 72)
# #time sub-sample cells: 0.1408s
# #time sub-sample counts: 3.9635s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (2865, 72)
# #time sub-sample cells: 0.1106s
# #time sub-sample counts: 3.1057s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (2292, 72)
# #time sub-sample cells: 0.1169s
# #time sub-sample counts: 2.4508s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (1432, 72)
# #time sub-sample cells: 0.1210s
# #time sub-sample counts: 1.7669s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (1146, 72)
# #time sub-sample cells: 0.1167s
# #time sub-sample counts: 1.2429s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (45848, 72)
# #time sub-sample cells: 0.2070s
# ## 5000 cells processed
# ## 10000 cells processed
# ## 15000 cells processed
# ## 20000 cells processed
# ## 25000 cells processed
# ## 30000 cells processed
# ## 35000 cells processed
# ## 40000 cells processed
# ## 45000 cells processed
# #time sub-sample counts: 43.4292s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (22924, 72)
# #time sub-sample cells: 0.1664s
# ## 5000 cells processed
# ## 10000 cells processed
# ## 15000 cells processed
# ## 20000 cells processed
# #time sub-sample counts: 22.5748s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (11462, 72)
# #time sub-sample cells: 0.1260s
# ## 5000 cells processed
# ## 10000 cells processed
# #time sub-sample counts: 11.7608s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (7641, 72)
# #time sub-sample cells: 0.1519s
# ## 5000 cells processed
# #time sub-sample counts: 8.0407s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (5731, 72)
# #time sub-sample cells: 0.1526s
# ## 5000 cells processed
# #time sub-sample counts: 6.3247s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (4584, 72)
# #time sub-sample cells: 0.1253s
# #time sub-sample counts: 4.9005s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (2865, 72)
# #time sub-sample cells: 0.1428s
# #time sub-sample counts: 3.1721s
#
# #time start: 0.0s
# before cell subsamp (1306127, 72)
# after cell subsamp (2292, 72)
# #time sub-sample cells: 0.1314s
# #time sub-sample counts: 2.7498s

# %% [markdown]
# # density deconvolution

# %%
gene = data_13m.var_names[0]
temp_full = data_13m[:,gene].X
temp_full = np.array(temp_full,dtype=int)
temp_full = temp_full.reshape(-1)

temp = data_subsamp[list(data_subsamp.keys())[5]][:,gene].X
temp = np.array(temp,dtype=int)
temp = temp.reshape(-1)

# %%
plt.figure(figsize=[18,10])
plt.subplot(211)
plt.hist(temp_full,bins=np.linspace(0,60,61))
plt.title('full %s'%gene)
plt.subplot(212)
plt.hist(temp,bins=np.linspace(0,20,21))
plt.title('subsample %s'%gene)
plt.show()

# %%
p_hat,x_hat=dd1d.dd_1d(temp,noise='poi',zero_inflate=True,c_reg=1e-6,verbose=False,gamma=None,debug_mode=False)

# %%
m_full = temp_full.mean()
m_sub = temp.mean()
m_hat = p_hat.dot(x)
x_rec = x/m_hat*m_full
x_step = x_rec[1]-x_rec[0]
plt.figure(figsize=[18,5])
plt.hist(temp*m_full/m_sub,bins=np.linspace(0,60,61),weights = np.ones(temp.shape[0])/temp.shape[0],alpha=0.5,label='full')
plt.hist(temp_full,bins=np.linspace(0,60,61),weights = np.ones(temp_full.shape[0])/temp_full.shape[0],alpha=0.5,label='subsample')
plt.plot(x_rec,p_hat/x_step,linewidth=4,label='dd')
plt.title('gene: %s, Nr_bar = %0.1f'%(gene,temp.mean()))
plt.xlim([0,60])
plt.legend()
plt.show()

# %%
# gene_list = list(data_13m.var_names[0:4])
gene_list = list(data_13m.var_names)
err_dd_dic_ = {}
err_ml_dic_ = {}
for key in data_subsamp.keys():
    err_dd_dic_[key] = np.zeros(len(gene_list))
    err_ml_dic_[key] = np.zeros(len(gene_list))

# %%
for i_gene,gene in enumerate(gene_list):
    temp_full = data_13m[:,gene].X
    temp_full = np.array(temp_full,dtype=int)
    temp_full = temp_full.reshape(-1)
    p_full,x_full=dd1d.counts2pdf_1d(temp_full)
    
    for key in data_subsamp.keys():
#         B_,Nr_bar_,Nr_,Nc_ = key
        temp = data_subsamp[key][:,gene].X
        temp = np.array(temp,dtype=int)
        temp = temp.reshape(-1)

        p_sub,x_sub=dd1d.counts2pdf_1d(temp)
        p_hat,x_hat=dd1d.dd_1d(temp,noise='poi',zero_inflate=True,c_reg=1e-6,verbose=False,gamma=None,debug_mode=False)

        m_full = p_full.dot(x_full)
        m_sub = p_sub.dot(x_sub)
        m_hat = p_hat.dot(x_hat)

        err_dd_dic_[key][i_gene]=dist_W1(p_hat,p_full,x_hat/m_hat*m_full,x_full)
        err_ml_dic_[key][i_gene]=dist_W1(p_sub,p_full,x_sub/m_sub*m_full,x_full)
#         Nr_list_.append(Nr_bar_)

# %%
plt.figure(figsize=[18,10])
plt.subplot(211)
for B_sub in B_sub_list:
    err_dd_ = []
    err_ml_ = []
    Nr_bar_list_ = []
    Nc_list_ = []
    
    for key in data_subsamp.keys():
        B_,Nr_bar_,Nr_,Nc_ = key
        if B_ == B_sub:
            Nr_bar_list_.append(Nr_bar_)
            Nc_list_.append(Nc_)
            err_ml_.append(np.log10(err_ml_dic_[key].mean()))
            err_dd_.append(np.log10(err_dd_dic_[key].mean()))
    
    err_ml_ = np.array(err_ml_)
    err_dd_ = np.array(err_dd_)
    Nr_bar_list_ = np.array(Nr_bar_list_)
    Nc_list_ = np.array(Nc_list_)
    
    sort_idx = np.argsort(Nr_bar_list_)
    err_ml_ = err_ml_[sort_idx]
    err_dd_ = err_dd_[sort_idx]
    Nr_bar_list_ = Nr_bar_list_[sort_idx]
    Nc_list_ = Nc_list_[sort_idx]
    
    plt.plot(Nr_bar_list_,err_dd_,label='dd,B=%d'%B_sub,marker='o',color='orange')
    plt.plot(Nr_bar_list_,err_ml_,label='ml,B=%d'%B_sub,marker='o',color='steelblue')
plt.legend()    
plt.ylabel('log10 MMSE')
plt.xlabel('mean read cts per gene per cell')
plt.subplot(212)

for B_sub in B_sub_list:
    err_dd_ = []
    err_ml_ = []
    Nr_bar_list_ = []
    Nc_list_ = []
    
    for key in data_subsamp.keys():
        B_,Nr_bar_,Nr_,Nc_ = key
        if B_ == B_sub:
            Nr_bar_list_.append(Nr_bar_)
            Nc_list_.append(Nc_)
            err_ml_.append(err_ml_dic_[key].mean())
            err_dd_.append(err_dd_dic_[key].mean())
    
    err_ml_ = np.array(err_ml_)
    err_dd_ = np.array(err_dd_)
    Nr_bar_list_ = np.array(Nr_bar_list_)
    Nc_list_ = np.array(Nc_list_)
    
    sort_idx = np.argsort(Nr_bar_list_)
    err_ml_ = err_ml_[sort_idx]
    err_dd_ = err_dd_[sort_idx]
    Nr_bar_list_ = Nr_bar_list_[sort_idx]
    Nc_list_ = Nc_list_[sort_idx]
    
    plt.plot(Nr_bar_list_,Nc_list_,label='B=%d'%B_sub,marker='o')
plt.legend()    
plt.xlabel('mean read cts per gene per cell')
plt.show()

# %%
plt.figure(figsize=[18,10])
plt.subplot(211)
for B_sub in B_sub_list:
    err_dd_ = []
    err_ml_ = []
    Nr_bar_list_ = []
    Nc_list_ = []
    
    for key in data_subsamp.keys():
        B_,Nr_bar_,Nr_,Nc_ = key
        if B_ == B_sub:
            Nr_bar_list_.append(Nr_bar_)
            Nc_list_.append(Nc_)
            err_ml_.append(np.log10(err_ml_dic_[key].mean()))
            err_dd_.append(np.log10(err_dd_dic_[key].mean()))
    
    err_ml_ = np.array(err_ml_)
    err_dd_ = np.array(err_dd_)
    Nr_bar_list_ = np.array(Nr_bar_list_)
    Nc_list_ = np.array(Nc_list_)
    
    sort_idx = np.argsort(Nr_bar_list_)
    err_ml_ = err_ml_[sort_idx]
    err_dd_ = err_dd_[sort_idx]
    Nr_bar_list_ = Nr_bar_list_[sort_idx]
    Nc_list_ = Nc_list_[sort_idx]
    
    plt.plot(Nr_bar_list_,err_dd_,label='dd,B=%d'%B_sub,marker='o')#,color='orange')
#     plt.plot(Nr_bar_list_,err_ml_,label='ml,B=%d'%B_sub,marker='o',color='steelblue')
plt.legend()    
plt.subplot(212)

for B_sub in B_sub_list:
    err_dd_ = []
    err_ml_ = []
    Nr_bar_list_ = []
    Nc_list_ = []
    
    for key in data_subsamp.keys():
        B_,Nr_bar_,Nr_,Nc_ = key
        if B_ == B_sub:
            Nr_bar_list_.append(Nr_bar_)
            Nc_list_.append(Nc_)
            err_ml_.append(err_ml_dic_[key].mean())
            err_dd_.append(err_dd_dic_[key].mean())
    
    err_ml_ = np.array(err_ml_)
    err_dd_ = np.array(err_dd_)
    Nr_bar_list_ = np.array(Nr_bar_list_)
    Nc_list_ = np.array(Nc_list_)
    
    sort_idx = np.argsort(Nr_bar_list_)
    err_ml_ = err_ml_[sort_idx]
    err_dd_ = err_dd_[sort_idx]
    Nr_bar_list_ = Nr_bar_list_[sort_idx]
    Nc_list_ = Nc_list_[sort_idx]
    
    plt.plot(Nr_bar_list_,Nc_list_,label='B=%d'%B_sub,marker='o')
plt.legend()    
plt.show()

# %%
for gene in data_13m.var_names[0:5]:

#     gene = data_13m3m3m.var_names[1]
    temp_full = data_13m[:,gene].X
    temp_full = np.array(temp_full,dtype=int)
    temp_full = temp_full.reshape(-1)
    p_full,x_full=dd1d.counts2pdf_1d(temp_full)

    err_dd = []
    err_ml = []
    Nr_list_ = []

    for key in data_subsamp.keys():
        B_,Nr_bar_,Nr_,Nc_ = key
        if B_ == B_sub_list[3]:
            temp = data_subsamp[key][:,gene].X
            temp = np.array(temp,dtype=int)
            temp = temp.reshape(-1)

            p_sub,x_sub=dd1d.counts2pdf_1d(temp)
            p_hat,x_hat=dd1d.dd_1d(temp,noise='poi',zero_inflate=True,c_reg=1e-6,verbose=False,gamma=None,debug_mode=False)

            m_full = p_full.dot(x_full)
            m_sub = p_sub.dot(x_sub)
            m_hat = p_hat.dot(x_hat)

            err_dd.append(dist_W1(p_hat,p_full,x_hat/m_hat*m_full,x_full))
            err_ml.append(dist_W1(p_sub,p_full,x_sub/m_sub*m_full,x_full))
            Nr_list_.append(Nr_bar_)
    plt.figure(figsize=[18,5])
    plt.plot(Nr_list_,err_dd,label='dd',marker='o')
    plt.plot(Nr_list_,err_ml,label='ml',marker='o')
    plt.legend()
    plt.title(gene)
    plt.xlabel('mean read cts per gene per cell')
    plt.show()
