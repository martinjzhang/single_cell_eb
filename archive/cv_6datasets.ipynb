# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import h5py
import os
import time

from util import *
from data_loader import * 
import scdd as sd

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/martin/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
dataset={}
dataname = ['brain9k','brain1k','PBMC8k','PBMC68k','brain2k','brain1.3m']
dataset['brain9k'] = load_10x_9k() ## 9k brain cells 
dataset['brain1k'] = load_10x_1k() ## 1k brain cells 
dataset['PBMC8k'] = load_10x_8k() ## 8k PBMC cells 
dataset['PBMC68k'] = load_10x_68k() ## 68k PBMC cells 
dataset['brain2k'] = load_10x_2k() ## 2k brain cells 
dataset['brain1.3m'] = load_10x_1_3mil() ## 1.3 million brain cells
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
del dataset

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-83fd341e0ebf> in <module>()
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# # estimation consistency

# %% [markdown]
# # old size_factor correction

# %%
M,M_ml,M_nsf,M_ml_nsf,gene_list,gene_list_nsf = {},{},{},{},{},{}

for dname in dataset.keys():
    if dname=='brain1.3m': break
    print('## processing %s ...'%dname)
    print('# n_cell=%d, n_gene=%d'%(dataset[dname].shape[0],dataset[dname].shape[1]))
    temp = dataset[dname].copy()
    sc.pp.filter_cells(temp, min_counts=0.01*temp.shape[1])
    gamma_c = sd.dd_size_factor(temp,verbose=False)
    sc.pp.filter_genes(temp,min_counts=0.01*temp.shape[0])
    print('# after filtering: n_cell=%d, n_gene=%d'%(temp.shape[0],temp.shape[1]))
    M_,M_ml_,gene_list_ = sd.dd_moment_anndata(temp,gamma_c=gamma_c,verbose=False)
    M_nsf_,M_ml_nsf_,gene_list_nsf_ = sd.dd_moment_anndata(temp,gamma_c=None,verbose=False)
    
    M[dname],M_ml[dname],M_nsf[dname],M_ml_nsf[dname],gene_list[dname],gene_list_nsf[dname] = \
    M_,M_ml_,M_nsf_,M_ml_nsf_,gene_list_,gene_list_nsf_
    print('\n')
#     if dname=='PBMC8k': break
# Out:
# ## processing brain9k ...
# # n_cell=9128, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=9128, n_gene=12484
#
#
# ## processing brain1k ...
# # n_cell=931, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=931, n_gene=12343
#
#
# ## processing PBMC8k ...
# # n_cell=8381, n_gene=33694
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=8381, n_gene=11062
#
#
# ## processing PBMC68k ...
# # n_cell=68579, n_gene=32738
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=68579, n_gene=6723
#
#
# ## processing brain2k ...
# # n_cell=2022, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=2022, n_gene=12305

# %%
plot_list = [['brain9k','brain1k'],['brain9k','brain2k'],['brain9k','brain1.3m']]
plot_list = [['brain1k','brain2k'],['brain1k','brain9k'],['brain1k','brain1.3m']]
plot_list = [['brain1k','brain2k'],['brain1k','brain9k'],['PBMC8k','PBMC68k'],['brain1k','brain1.3m']]

# plot_list = [['brain9k','brain1k']]
for pair in plot_list:    
    d1,d2=pair
    print('## %s vs %s'%(d1,d2))
    sd.fig_xx_cv(M[d1],M_ml[d1],M[d2],M_ml[d2],gene_list[d1],gene_list[d2],[d1,d2],mean_fil=0.5)    
#     sd.fig_xx_cv(M_nsf[d1],M_ml_nsf[d1],M_nsf[d2],M_ml_nsf[d2],gene_list_nsf[d1],gene_list_nsf[d2],[d1,d2],mean_fil=0.5)
# Out:
# ## brain1k vs brain2k
# ml: above=853, below=327, avg_r log10(cv2/cv1)=0.043
# dd: above=304, below=876, avg_r log10(cv2/cv1)=-0.159
# ## brain1k vs brain9k
# ml: above=1382, below=163, avg_r log10(cv2/cv1)=0.095
# dd: above=878, below=667, avg_r log10(cv2/cv1)=0.026
# ## PBMC8k vs PBMC68k
# ml: above=223, below=23, avg_r log10(cv2/cv1)=0.151
# dd: above=155, below=91, avg_r log10(cv2/cv1)=0.069
# ## brain1k vs brain1.3m
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-58839c664c32> in <module>()
#       7     d1,d2=pair
#       8     print('## %s vs %s'%(d1,d2))
# ----> 9     sd.fig_xx_cv(M[d1],M_ml[d1],M[d2],M_ml[d2],gene_list[d1],gene_list[d2],[d1,d2],mean_fil=0.5)
#      10 #     sd.fig_xx_cv(M_nsf[d1],M_ml_nsf[d1],M_nsf[d2],M_ml_nsf[d2],gene_list_nsf[d1],gene_list_nsf[d2],[d1,d2],mean_fil=0.5)
#
# KeyError: 'brain1.3m'

# %% [markdown]
# # New size factor correction

# %%
np.save('./results/xx_plot/M.npy',M)
np.save('./results/xx_plot/M_ml.npy',M_ml)
np.save('./results/xx_plot/gene_list.npy',gene_list)

# %%
M,M_ml,M_nsf,M_ml_nsf,gene_list,gene_list_nsf = {},{},{},{},{},{}

for dname in dataset.keys():
#     if dname=='brain1.3m': break
    print('## processing %s ...'%dname)
    print('# n_cell=%d, n_gene=%d'%(dataset[dname].shape[0],dataset[dname].shape[1]))
    temp = dataset[dname].copy()
    sc.pp.filter_cells(temp, min_counts=0.01*temp.shape[1])
    size_factor = sd.dd_size_factor(temp,verbose=False)
    sc.pp.filter_genes(temp,min_counts=0.1*temp.shape[0])
    print('# after filtering: n_cell=%d, n_gene=%d'%(temp.shape[0],temp.shape[1]))
    
    gene_list_ = list(temp.var_names)    
    M_ml_,M_ = sd.dd_1d_moment(temp,size_factor=size_factor)
    M_ml_ = M_ml_.T
    M_ = M_.T
    
    M[dname],M_ml[dname],gene_list[dname] = M_,M_ml_,gene_list_    
    print('\n')
#     if dname=='PBMC8k': break
# Out:
# ## processing brain9k ...
# # n_cell=9128, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=9128, n_gene=7578
# #time start: 0.0s
# n_cell=9128, n_gene=7578
# #total: 0.47s
#
#
# ## processing brain1k ...
# # n_cell=931, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=931, n_gene=8124
# #time start: 0.0s
# n_cell=931, n_gene=8124
# #total: 0.05s
#
#
# ## processing PBMC8k ...
# # n_cell=8381, n_gene=33694
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=8381, n_gene=4329
# #time start: 0.0s
# n_cell=8381, n_gene=4329
# #total: 0.16s
#
#
# ## processing PBMC68k ...
# # n_cell=68579, n_gene=32738
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=68579, n_gene=1385
# #time start: 0.0s
# n_cell=68579, n_gene=1385
# #total: 0.44s
#
#
# ## processing brain2k ...
# # n_cell=2022, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=2022, n_gene=7060
# #time start: 0.0s
# n_cell=2022, n_gene=7060
# #total: 0.07s
#
#
# ## processing brain1.3m ...
# # n_cell=1306127, n_gene=27998
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# # after filtering: n_cell=1306127, n_gene=6263
# #time start: 0.0s
# n_cell=1306127, n_gene=6263
# #total: 227.38s

# %%
## change all the gene names to upper-case 
for gl in gene_list.keys():
    temp = gene_list[gl]
    for i in range(len(temp)):
        temp[i] = temp[i].upper()
    gene_list[gl] = temp
# for gl in gene_list.keys():
#     temp = gene_list_nsf[gl]
#     for i in range(len(temp)):
#         temp[i] = temp[i].upper()
#     gene_list_nsf[gl] = temp

# %%
dataset.keys()
# Out:
# dict_keys(['brain9k', 'brain1k', 'PBMC8k', 'PBMC68k', 'brain2k', 'brain1.3m'])

# %%
plot_list = [['brain1k','brain2k'],['brain1k','brain9k'],['PBMC8k','PBMC68k'],['brain1k','brain1.3m']]
# plot_list = [,['brain1k','brain9k'],['brain1k','brain1.3m']]
# plot_list = [['brain9k','brain1k']]
for pair in plot_list:    
    d1,d2=pair
    print('## %s vs %s'%(d1,d2))
    sd.fig_xx_cv(M[d1],M_ml[d1],M[d2],M_ml[d2],gene_list[d1],gene_list[d2],[d1,d2],mean_fil=0.5)    
#     sd.fig_xx_cv(M_nsf[d1],M_ml_nsf[d1],M_nsf[d2],M_ml_nsf[d2],gene_list_nsf[d1],gene_list_nsf[d2],[d1,d2],mean_fil=0.5)
# Out:
# ## brain1k vs brain2k
# ml: above=1231, below=557, avg_r log10(cv2/cv1)=0.024
# dd: above=352, below=1436, avg_r log10(cv2/cv1)=-0.135
# ## brain1k vs brain9k
# ml: above=1779, below=214, avg_r log10(cv2/cv1)=0.059
# dd: above=1074, below=919, avg_r log10(cv2/cv1)=0.003
# ## PBMC8k vs PBMC68k
# ml: above=250, below=24, avg_r log10(cv2/cv1)=0.148
# dd: above=176, below=98, avg_r log10(cv2/cv1)=0.093
# ## brain1k vs brain1.3m
# ml: above=1467, below=20, avg_r log10(cv2/cv1)=0.131
# dd: above=1030, below=457, avg_r log10(cv2/cv1)=0.045

# %% [markdown]
# # high vs low experiments

# %%
dataset.keys()
# Out:
# dict_keys(['brain9k', 'brain1k', 'PBMC8k', 'PBMC68k', 'brain2k', 'brain1.3m'])

# %% [markdown]
# ### the sequencing depth seems to be
# 1k > 9k > 2k > 1.3m

# %%
## generate a mean sequencing depth plot 
plt.figure(figsize=[18,5])
bins = np.linspace(-1,4,20)
for dname in ['brain1k','brain2k','brain9k','brain1.3m']:
    data = dataset[dname].copy()
    sc.pp.filter_genes(data,min_counts=0.1*data.shape[0])
    mean_g = np.array(data.X.mean(axis=0),dtype=float).reshape(-1)
    plt.hist(np.log10(mean_g),alpha=0.3,bins=bins,label=dname)
plt.legend()
plt.show()
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-ef1ceeeb5056> in <module>()
#       3 bins = np.linspace(-1,4,20)
#       4 for dname in ['brain1k','brain2k','brain9k','brain1.3m']:
# ----> 5     data = dataset[dname].copy()
#       6     sc.pp.filter_genes(data,min_counts=0.1*data.shape[0])
#       7     mean_g = np.array(data.X.mean(axis=0),dtype=float).reshape(-1)
#
# KeyError: 'brain1.3m'

# %%
d_deep = 'brain1k'
d_shallow = 'brain1.3m'
gene_list_ = []
idx_deep = []
idx_shallow = []

for gene in gene_list[d_deep]:   
    if (gene.upper() in gene_list[d_deep]) and (gene.upper() in gene_list[d_shallow]):
        temp_deep = gene_list[d_deep].index(gene.upper())
        temp_shallow = gene_list[d_shallow].index(gene.upper())
    else: 
        continue
#     if (M_ml_nsf[d_shallow][temp_shallow,0]<1) and (M_ml_nsf[d_deep][temp_deep,0]>2):
    if (M_ml[d_shallow][temp_shallow,0]<1) and (M_ml[d_deep][temp_deep,0]>1.5):
        gene_list_.append(gene)
        idx_deep.append(temp_deep)
        idx_shallow.append(temp_shallow)
#         print('gene: %s, mean_shallow=%0.3f, mean_deep=%0.3f'
#               %(gene,M_ml_nsf[d_shallow][temp_shallow,0],
#                 M[d_deep][temp_deep,0]))
        
        print('gene: %s, mean_shallow=%0.3f, mean_deep=%0.3f'
              %(gene,M_ml[d_shallow][temp_shallow,0],
                M[d_deep][temp_deep,0]))
# Out:
# gene: MRPL15, mean_shallow=0.542, mean_deep=1.630
# gene: SNHG6, mean_shallow=0.545, mean_deep=1.937
# gene: COPS5, mean_shallow=0.701, mean_deep=1.873
# gene: TXNDC9, mean_shallow=0.856, mean_deep=1.917
# gene: MAP4K4, mean_shallow=0.673, mean_deep=1.739
# gene: NDUFB3, mean_shallow=0.937, mean_deep=2.527
# gene: IGFBP2, mean_shallow=0.766, mean_deep=2.206
# gene: COPS8, mean_shallow=0.641, mean_deep=1.559
# gene: HES6, mean_shallow=0.996, mean_deep=2.740
# gene: NDUFA10, mean_shallow=0.957, mean_deep=2.583
# gene: DTYMK, mean_shallow=0.583, mean_deep=1.562
# gene: NUCKS1, mean_shallow=0.796, mean_deep=1.715
# gene: CNTN2, mean_shallow=0.735, mean_deep=2.464
# gene: BTG2, mean_shallow=0.630, mean_deep=2.107
# gene: ARL8A, mean_shallow=0.510, mean_deep=1.570
# gene: GLRX2, mean_shallow=0.761, mean_deep=1.944
# gene: IER5, mean_shallow=0.656, mean_deep=1.886
# gene: ACBD6, mean_shallow=0.607, mean_deep=1.558
# gene: MRPS14, mean_shallow=0.732, mean_deep=1.863
# gene: PRDX6, mean_shallow=0.868, mean_deep=2.236
# gene: MPC2, mean_shallow=0.904, mean_deep=2.597
# gene: NDUFS2, mean_shallow=0.863, mean_deep=2.493
# gene: PEA15A, mean_shallow=0.926, mean_deep=2.088
# gene: IGSF8, mean_shallow=0.591, mean_deep=2.027
# gene: COX20, mean_shallow=0.668, mean_deep=1.657
# gene: RBM17, mean_shallow=0.654, mean_deep=1.791
# gene: MRPL41, mean_shallow=0.535, mean_deep=1.607
# gene: TUBB4B, mean_shallow=0.911, mean_deep=2.960
# gene: SSNA1, mean_shallow=0.613, mean_deep=1.583
# gene: NPDC1, mean_shallow=0.905, mean_deep=2.460
# gene: MED22, mean_shallow=0.700, mean_deep=1.917
# gene: BRD3, mean_shallow=0.832, mean_deep=1.864
# gene: OLFM1, mean_shallow=0.702, mean_deep=1.673
# gene: ARPC5L, mean_shallow=0.781, mean_deep=1.915
# gene: PRPF40A, mean_shallow=0.818, mean_deep=1.615
# gene: PSMD14, mean_shallow=0.953, mean_deep=2.268
# gene: PPIG, mean_shallow=0.837, mean_deep=1.709
# gene: SSRP1, mean_shallow=0.799, mean_deep=2.292
# gene: MTCH2, mean_shallow=0.924, mean_deep=2.730
# gene: NDUFS3, mean_shallow=0.909, mean_deep=2.387
# gene: PSMC3, mean_shallow=0.794, mean_deep=2.129
# gene: CCDC34, mean_shallow=0.793, mean_deep=2.228
# gene: DUT, mean_shallow=0.723, mean_deep=2.060
# gene: NOP56, mean_shallow=0.797, mean_deep=1.968
# gene: NSFL1C, mean_shallow=0.584, mean_deep=1.508
# gene: EIF6, mean_shallow=0.590, mean_deep=1.548
# gene: ERGIC3, mean_shallow=0.837, mean_deep=2.073
# gene: DLGAP4, mean_shallow=0.908, mean_deep=2.401
# gene: 1110008F13RIK, mean_shallow=0.646, mean_deep=1.759
# gene: UBE2C, mean_shallow=0.537, mean_deep=1.838
# gene: FAM210B, mean_shallow=0.700, mean_deep=2.071
# gene: RAE1, mean_shallow=0.484, mean_deep=1.505
# gene: POLR3K, mean_shallow=0.744, mean_deep=1.844
# gene: PCSK1N, mean_shallow=0.955, mean_deep=1.722
# gene: NDUFA1, mean_shallow=0.771, mean_deep=2.122
# gene: IDH3G, mean_shallow=0.599, mean_deep=1.657
# gene: SSR4, mean_shallow=0.777, mean_deep=1.962
# gene: PJA1, mean_shallow=0.716, mean_deep=1.678
# gene: TSPAN6, mean_shallow=0.705, mean_deep=1.591
# gene: BEX4, mean_shallow=0.864, mean_deep=2.131
# gene: TCEAL8, mean_shallow=0.751, mean_deep=1.597
# gene: BEX1, mean_shallow=0.853, mean_deep=2.168
# gene: MAGED2, mean_shallow=0.671, mean_deep=1.662
# gene: HSD17B10, mean_shallow=0.647, mean_deep=1.750
# gene: 1810022K09RIK, mean_shallow=0.551, mean_deep=1.808
# gene: SEC62, mean_shallow=0.926, mean_deep=2.030
# gene: ACTL6A, mean_shallow=0.548, mean_deep=1.635
# gene: MEX3A, mean_shallow=0.617, mean_deep=1.931
# gene: LAMTOR2, mean_shallow=0.913, mean_deep=2.230
# gene: SSR2, mean_shallow=0.895, mean_deep=2.121
# gene: FDPS, mean_shallow=0.914, mean_deep=2.353
# gene: CHTOP, mean_shallow=0.826, mean_deep=1.883
# gene: VPS72, mean_shallow=0.789, mean_deep=2.250
# gene: MRPS21, mean_shallow=0.828, mean_deep=2.264
# gene: GSTM5, mean_shallow=0.803, mean_deep=2.013
# gene: SARS, mean_shallow=0.904, mean_deep=2.209
# gene: 1810037I17RIK, mean_shallow=0.709, mean_deep=1.779
# gene: OSTC, mean_shallow=0.878, mean_deep=2.269
# gene: AIMP1, mean_shallow=0.764, mean_deep=1.883
# gene: PPP3CA, mean_shallow=0.975, mean_deep=1.975
# gene: EIF4E, mean_shallow=0.895, mean_deep=1.803
# gene: LMO4, mean_shallow=0.937, mean_deep=2.617
# gene: DDAH1, mean_shallow=0.564, mean_deep=1.584
# gene: NDUFB6, mean_shallow=0.920, mean_deep=2.806
# gene: BAG1, mean_shallow=0.994, mean_deep=2.669
# gene: CCL27A, mean_shallow=0.617, mean_deep=1.671
# gene: ANP32B, mean_shallow=0.998, mean_deep=2.407
# gene: RAD23B, mean_shallow=0.863, mean_deep=1.524
# gene: CDC26, mean_shallow=0.806, mean_deep=1.826
# gene: RRAGA, mean_shallow=0.639, mean_deep=1.660
# gene: MLLT3, mean_shallow=0.868, mean_deep=1.608
# gene: SSBP3, mean_shallow=0.453, mean_deep=1.603
# gene: MAGOH, mean_shallow=0.775, mean_deep=2.016
# gene: SCP2, mean_shallow=0.743, mean_deep=1.766
# gene: ELAVL4, mean_shallow=0.791, mean_deep=1.559
# gene: NASP, mean_shallow=0.979, mean_deep=2.390
# gene: ERI3, mean_shallow=0.657, mean_deep=1.708
# gene: EBNA1BP2, mean_shallow=0.632, mean_deep=1.658
# gene: POU3F1, mean_shallow=0.378, mean_deep=1.514
# gene: TRAPPC3, mean_shallow=0.691, mean_deep=1.790
# gene: RBBP4, mean_shallow=0.893, mean_deep=2.119
# gene: TMEM234, mean_shallow=0.728, mean_deep=1.652
# gene: DNAJC8, mean_shallow=0.979, mean_deep=2.443
# gene: STX12, mean_shallow=0.838, mean_deep=1.667
# gene: TMEM50A, mean_shallow=0.712, mean_deep=1.701
# gene: SRRM1, mean_shallow=0.913, mean_deep=1.593
# gene: SRSF10, mean_shallow=0.782, mean_deep=1.527
# gene: CAPZB, mean_shallow=0.955, mean_deep=2.623
# gene: MFAP2, mean_shallow=0.893, mean_deep=2.528
# gene: CTNNBIP1, mean_shallow=0.959, mean_deep=2.310
# gene: RER1, mean_shallow=0.600, mean_deep=1.638
# gene: SSU72, mean_shallow=0.626, mean_deep=1.605
# gene: AURKAIP1, mean_shallow=0.727, mean_deep=1.712
# gene: PSMC2, mean_shallow=0.595, mean_deep=1.745
# gene: SRPK2, mean_shallow=0.814, mean_deep=1.631
# gene: DPYSL5, mean_shallow=0.769, mean_deep=1.883
# gene: OST4, mean_shallow=0.620, mean_deep=1.796
# gene: PPM1G, mean_shallow=0.596, mean_deep=1.537
# gene: MRPL33, mean_shallow=0.659, mean_deep=1.777
# gene: LRPAP1, mean_shallow=0.523, mean_deep=1.589
# gene: MED28, mean_shallow=0.918, mean_deep=2.427
# gene: SMIM14, mean_shallow=0.892, mean_deep=1.793
# gene: UBE2K, mean_shallow=0.900, mean_deep=1.956
# gene: OCIAD1, mean_shallow=0.787, mean_deep=1.749
# gene: CCNI, mean_shallow=0.937, mean_deep=2.420
# gene: HNRNPD, mean_shallow=0.677, mean_deep=2.559
# gene: COPS4, mean_shallow=0.619, mean_deep=1.563
# gene: RNF10, mean_shallow=0.942, mean_deep=1.512
# gene: ERP29, mean_shallow=0.849, mean_deep=2.162
# gene: VPS29, mean_shallow=0.784, mean_deep=1.673
# gene: BCL7A, mean_shallow=0.784, mean_deep=1.779
# gene: DENR, mean_shallow=0.682, mean_deep=1.644
# gene: CDK2AP1, mean_shallow=0.587, mean_deep=1.643
# gene: MRPS17, mean_shallow=0.794, mean_deep=2.975
# gene: ACTL6B, mean_shallow=0.675, mean_deep=1.631
# gene: COPS6, mean_shallow=0.886, mean_deep=2.437
# gene: LAMTOR4, mean_shallow=0.693, mean_deep=1.518
# gene: MMD2, mean_shallow=0.601, mean_deep=1.589
# gene: FAM220A, mean_shallow=0.759, mean_deep=2.383
# gene: BUD31, mean_shallow=0.792, mean_deep=2.160
# gene: LSM8, mean_shallow=0.833, mean_deep=1.871
# gene: SSBP1, mean_shallow=0.619, mean_deep=1.651
# gene: EZH2, mean_shallow=0.871, mean_deep=2.300
# gene: ATP6V0E2, mean_shallow=0.782, mean_deep=1.714
# gene: LSM5, mean_shallow=0.759, mean_deep=1.710
# gene: SUCLG1, mean_shallow=0.608, mean_deep=1.664
# gene: WBP1, mean_shallow=0.631, mean_deep=1.785
# gene: EMX1, mean_shallow=0.442, mean_deep=1.697
# gene: SNRNP27, mean_shallow=0.836, mean_deep=2.024
# gene: RAB7, mean_shallow=0.937, mean_deep=2.160
# gene: LSM3, mean_shallow=0.733, mean_deep=1.576
# gene: FRMD4B, mean_shallow=0.728, mean_deep=1.714
# gene: ZFP422, mean_shallow=0.923, mean_deep=1.571
# gene: ZFP637, mean_shallow=0.800, mean_deep=2.216
# gene: EMG1, mean_shallow=0.913, mean_deep=2.211
# gene: ING4, mean_shallow=0.960, mean_deep=2.265
# gene: CHD4, mean_shallow=0.865, mean_deep=1.681
# gene: MRPL51, mean_shallow=0.590, mean_deep=1.597
# gene: H2AFJ, mean_shallow=0.690, mean_deep=1.772
# gene: STRAP, mean_shallow=0.928, mean_deep=2.025
# gene: TSEN34, mean_shallow=0.914, mean_deep=2.194
# gene: TRIM28, mean_shallow=0.808, mean_deep=2.230
# gene: CHMP2A, mean_shallow=0.986, mean_deep=2.421
# gene: GLTSCR2, mean_shallow=0.966, mean_deep=2.557
# gene: NAPA, mean_shallow=0.577, mean_deep=1.580
# gene: SAE1, mean_shallow=0.579, mean_deep=1.740
# gene: RABAC1, mean_shallow=0.782, mean_deep=1.993
# gene: SNRPA, mean_shallow=0.797, mean_deep=2.204
# gene: PSMC4, mean_shallow=0.975, mean_deep=2.996
# gene: FBL, mean_shallow=0.947, mean_deep=2.592
# gene: CAPNS1, mean_shallow=0.668, mean_deep=1.779
# gene: POLR2I, mean_shallow=0.774, mean_deep=1.909
# gene: CLIP3, mean_shallow=0.802, mean_deep=2.268
# gene: PSENEN, mean_shallow=0.797, mean_deep=2.246
# gene: RBM42, mean_shallow=0.534, mean_deep=1.517
# gene: TMEM147, mean_shallow=0.626, mean_deep=1.842
# gene: SNRNP70, mean_shallow=0.977, mean_deep=2.545
# gene: SNRPA1, mean_shallow=0.611, mean_deep=1.716
# gene: RLBP1, mean_shallow=0.544, mean_deep=1.547
# gene: IDH2, mean_shallow=0.658, mean_deep=2.088
# gene: SEC11A, mean_shallow=0.642, mean_deep=1.722
# gene: ZFAND6, mean_shallow=0.931, mean_deep=1.541
# gene: CLNS1A, mean_shallow=0.606, mean_deep=1.729
# gene: SPCS2, mean_shallow=0.973, mean_deep=2.178
# gene: LAMTOR1, mean_shallow=0.718, mean_deep=1.806
# gene: LMO1, mean_shallow=0.800, mean_deep=1.605
# gene: EIF3C, mean_shallow=0.920, mean_deep=2.322
# gene: BOLA2, mean_shallow=0.780, mean_deep=1.637
# gene: ALDOA, mean_shallow=0.923, mean_deep=2.106
# gene: DCTPP1, mean_shallow=0.787, mean_deep=2.164
# gene: BUB3, mean_shallow=0.787, mean_deep=2.313
# gene: PSMD13, mean_shallow=0.714, mean_deep=1.914
# gene: MRPL23, mean_shallow=0.954, mean_deep=2.322
# gene: PCMT1, mean_shallow=0.717, mean_deep=1.634
# gene: SF3B5, mean_shallow=0.826, mean_deep=2.333
# gene: RWDD1, mean_shallow=0.906, mean_deep=2.265
# gene: SNX3, mean_shallow=0.877, mean_deep=1.774
# gene: SERINC1, mean_shallow=0.864, mean_deep=1.585
# gene: DDIT4, mean_shallow=0.596, mean_deep=1.613
# gene: PPA1, mean_shallow=0.796, mean_deep=2.375
# gene: UBE2D1, mean_shallow=0.792, mean_deep=1.768
# gene: CISD1, mean_shallow=0.999, mean_deep=2.627
# gene: ZWINT, mean_shallow=0.843, mean_deep=1.836
# gene: PLPPR3, mean_shallow=0.576, mean_deep=1.611
# gene: R3HDM4, mean_shallow=0.797, mean_deep=2.111
# gene: POLR2E, mean_shallow=0.812, mean_deep=2.151
# gene: NDUFS7, mean_shallow=0.899, mean_deep=2.100
# gene: PLEKHJ1, mean_shallow=0.594, mean_deep=1.629
# gene: SGTA, mean_shallow=0.941, mean_deep=2.241
# gene: MAP2K2, mean_shallow=0.959, mean_deep=2.512
# gene: AES, mean_shallow=0.957, mean_deep=2.957
# gene: HSP90B1, mean_shallow=0.886, mean_deep=1.837
# gene: ARL1, mean_shallow=0.736, mean_deep=1.609
# gene: TMPO, mean_shallow=0.977, mean_deep=1.871
# gene: MRPL42, mean_shallow=0.751, mean_deep=1.974
# gene: CSRP2, mean_shallow=0.895, mean_deep=2.752
# gene: RPL6L, mean_shallow=0.340, mean_deep=1.585
# gene: YEATS4, mean_shallow=0.801, mean_deep=1.857
# gene: LLPH, mean_shallow=0.770, mean_deep=1.870
# gene: PTGES3, mean_shallow=0.881, mean_deep=1.635
# gene: CNPY2, mean_shallow=0.768, mean_deep=1.922
# gene: NABP2, mean_shallow=0.556, mean_deep=1.603
# gene: PA2G4, mean_shallow=0.819, mean_deep=2.418
# gene: CD63, mean_shallow=0.656, mean_deep=1.565
# gene: ARGLU1, mean_shallow=0.775, mean_deep=1.533
# gene: LAMP1, mean_shallow=0.942, mean_deep=1.967
# gene: GOLGA7, mean_shallow=0.659, mean_deep=1.537
# gene: TM2D2, mean_shallow=0.639, mean_deep=1.590
# gene: SARAF, mean_shallow=0.646, mean_deep=1.505
# gene: NCAN, mean_shallow=0.948, mean_deep=1.675
# gene: COPE, mean_shallow=0.927, mean_deep=2.377
# gene: 2810428I15RIK, mean_shallow=0.858, mean_deep=1.862
# gene: UBA52, mean_shallow=0.982, mean_deep=1.914
# gene: CCDC124, mean_shallow=0.842, mean_deep=2.402
# gene: USE1, mean_shallow=0.876, mean_deep=2.363
# gene: MRPL34, mean_shallow=0.891, mean_deep=2.442
# gene: DDA1, mean_shallow=0.767, mean_deep=1.983
# gene: SIN3B, mean_shallow=0.825, mean_deep=1.967
# gene: RBMXL1, mean_shallow=0.875, mean_deep=2.506
# gene: LSM6, mean_shallow=0.953, mean_deep=2.394
# gene: IER2, mean_shallow=0.687, mean_deep=2.419
# gene: WDR83OS, mean_shallow=0.639, mean_deep=1.539
# gene: DNAJA2, mean_shallow=0.856, mean_deep=1.773
# gene: ARL2BP, mean_shallow=0.661, mean_deep=1.722
# gene: POLR2C, mean_shallow=0.792, mean_deep=1.978
# gene: GM8730, mean_shallow=0.556, mean_deep=2.465
# gene: FAM96B, mean_shallow=0.753, mean_deep=2.061
# gene: ATP6V0D1, mean_shallow=0.914, mean_deep=2.296
# gene: COTL1, mean_shallow=0.984, mean_deep=3.249
# gene: APRT, mean_shallow=0.926, mean_deep=2.190
# gene: TRAPPC2L, mean_shallow=0.703, mean_deep=1.608
# gene: THOC7, mean_shallow=0.956, mean_deep=2.435
# gene: PSMD6, mean_shallow=0.893, mean_deep=2.373
# gene: UBE2E1, mean_shallow=0.936, mean_deep=2.182
# gene: CHCHD1, mean_shallow=1.000, mean_deep=2.748
# gene: SPCS1, mean_shallow=0.980, mean_deep=2.447
# gene: NISCH, mean_shallow=0.990, mean_deep=2.109
# gene: RPL23A-PS3, mean_shallow=0.319, mean_deep=3.032
# gene: PSMC6, mean_shallow=0.922, mean_deep=1.976
# gene: APEX1, mean_shallow=0.902, mean_deep=2.911
# gene: PABPN1, mean_shallow=0.450, mean_deep=1.886
# gene: PSME1, mean_shallow=0.806, mean_deep=2.100
# gene: CTSB, mean_shallow=0.638, mean_deep=1.740
# gene: FDFT1, mean_shallow=0.614, mean_deep=2.025
# gene: SERP2, mean_shallow=0.721, mean_deep=1.832
# gene: UCHL3, mean_shallow=0.834, mean_deep=2.319
# gene: GM10076, mean_shallow=0.897, mean_deep=2.316
# gene: DCUN1D5, mean_shallow=0.899, mean_deep=2.159
# gene: CWC15, mean_shallow=0.907, mean_deep=2.405
# gene: PIN1, mean_shallow=0.790, mean_deep=2.118
# gene: EIF3G, mean_shallow=0.891, mean_deep=2.587
# gene: CDC37, mean_shallow=0.760, mean_deep=2.162
# gene: SMARCA4, mean_shallow=0.811, mean_deep=2.368
# gene: ELOF1, mean_shallow=0.634, mean_deep=1.682
# gene: RP9, mean_shallow=0.574, mean_deep=1.648
# gene: OPCML, mean_shallow=0.820, mean_deep=2.049
# gene: NTM, mean_shallow=0.489, mean_deep=1.531
# gene: CLMP, mean_shallow=0.473, mean_deep=1.558
# gene: H2AFX, mean_shallow=0.527, mean_deep=1.793
# gene: ACAT1, mean_shallow=0.944, mean_deep=2.300
# gene: RCN2, mean_shallow=0.893, mean_deep=1.853
# gene: IMP3, mean_shallow=0.586, mean_deep=1.798
# gene: ISLR2, mean_shallow=0.953, mean_deep=1.559
# gene: RAB11A, mean_shallow=0.804, mean_deep=1.721
# gene: OAZ2, mean_shallow=0.895, mean_deep=2.130
# gene: POLR2M, mean_shallow=0.892, mean_deep=2.076
# gene: RNF7, mean_shallow=0.918, mean_deep=2.069
# gene: ANAPC13, mean_shallow=0.797, mean_deep=2.022
# gene: PCBP4, mean_shallow=0.954, mean_deep=2.529
# gene: GNAI2, mean_shallow=0.973, mean_deep=2.789
# gene: RHOA, mean_shallow=0.962, mean_deep=1.988
# gene: IMPDH2, mean_shallow=0.573, mean_deep=1.764
# gene: IP6K2, mean_shallow=0.852, mean_deep=2.028
# gene: CCDC12, mean_shallow=0.649, mean_deep=1.614
# gene: NKTR, mean_shallow=0.667, mean_deep=1.575
# gene: HIGD1A, mean_shallow=0.576, mean_deep=1.631
# gene: MRPS24, mean_shallow=0.883, mean_deep=2.281
# gene: RAB1A, mean_shallow=0.931, mean_deep=2.265
# gene: AHSA2, mean_shallow=0.798, mean_deep=2.032
# gene: FAM114A2, mean_shallow=0.607, mean_deep=2.288
# gene: SNAP47, mean_shallow=0.744, mean_deep=1.920
# gene: USP22, mean_shallow=0.778, mean_deep=1.764
# gene: MFAP4, mean_shallow=0.460, mean_deep=1.711
# gene: CENPV, mean_shallow=0.253, mean_deep=1.509
# gene: TRAPPC1, mean_shallow=0.644, mean_deep=1.624
# gene: TRP53, mean_shallow=0.653, mean_deep=1.627
# gene: TMEM256, mean_shallow=0.953, mean_deep=2.288
# gene: SPAG7, mean_shallow=0.741, mean_deep=1.602
# gene: C1QBP, mean_shallow=0.810, mean_deep=2.230
# gene: TXNDC17, mean_shallow=0.783, mean_deep=2.029
# gene: EMC6, mean_shallow=0.779, mean_deep=1.999
# gene: TRAF4, mean_shallow=0.565, mean_deep=1.505
# gene: ALDOC, mean_shallow=0.655, mean_deep=1.720
# gene: POLDIP2, mean_shallow=0.573, mean_deep=1.521
# gene: PSMD11, mean_shallow=0.879, mean_deep=2.377
# gene: GDPD1, mean_shallow=0.772, mean_deep=1.930
# gene: SUPT4A, mean_shallow=0.856, mean_deep=2.175
# gene: DYNLL2, mean_shallow=0.840, mean_deep=1.678
# gene: RAB5C, mean_shallow=0.631, mean_deep=1.637
# gene: COA3, mean_shallow=1.000, mean_deep=2.274
# gene: RND2, mean_shallow=0.402, mean_deep=1.512
# gene: RUNDC3A, mean_shallow=0.793, mean_deep=1.795
# gene: DCAKD, mean_shallow=0.551, mean_deep=1.842
# gene: LIMD2, mean_shallow=0.608, mean_deep=1.672
# gene: PSMC5, mean_shallow=0.832, mean_deep=2.478
# gene: FAM104A, mean_shallow=0.685, mean_deep=1.580
# gene: WBP2, mean_shallow=0.516, mean_deep=1.596
# gene: MRPL12, mean_shallow=0.696, mean_deep=1.770
# gene: FAM195B, mean_shallow=0.910, mean_deep=2.329
# gene: ARHGDIA, mean_shallow=0.825, mean_deep=2.579
# gene: GPS1, mean_shallow=0.713, mean_deep=1.931
# gene: RALA, mean_shallow=0.988, mean_deep=3.078
# gene: HIST1H2AP, mean_shallow=0.552, mean_deep=2.599
# gene: NOL7, mean_shallow=0.941, mean_deep=2.611
# gene: DEK, mean_shallow=0.750, mean_deep=2.178
# gene: CKS2, mean_shallow=0.588, mean_deep=1.833
# gene: GADD45G, mean_shallow=0.802, mean_deep=2.758
# gene: RAB24, mean_shallow=0.607, mean_deep=1.518
# gene: PRELID1, mean_shallow=0.768, mean_deep=2.028
# gene: TMED9, mean_shallow=0.823, mean_deep=2.106
# gene: HNRNPA0, mean_shallow=0.649, mean_deep=1.772
# gene: MED10, mean_shallow=0.645, mean_deep=1.839
# gene: PDCD6, mean_shallow=0.671, mean_deep=1.656
# gene: NR2F1, mean_shallow=0.975, mean_deep=2.737
# gene: NSA2, mean_shallow=0.770, mean_deep=2.129
# gene: PDIA6, mean_shallow=0.942, mean_deep=2.175
# gene: ODC1, mean_shallow=0.710, mean_deep=2.279
# gene: MYT1L, mean_shallow=0.913, mean_deep=1.975
# gene: SRP54B, mean_shallow=0.913, mean_deep=2.102
# gene: ACTR10, mean_shallow=0.618, mean_deep=1.631
# gene: WDR89, mean_shallow=0.601, mean_deep=1.504
# gene: ATP6V1D, mean_shallow=0.669, mean_deep=1.632
# gene: EIF2S1, mean_shallow=0.486, mean_deep=1.550
# gene: AHSA1, mean_shallow=0.659, mean_deep=1.806
# gene: SLIRP, mean_shallow=0.767, mean_deep=2.220
# gene: SNW1, mean_shallow=0.663, mean_deep=1.705
# gene: DDX24, mean_shallow=0.655, mean_deep=1.504
# gene: GLRX5, mean_shallow=0.674, mean_deep=1.921
# gene: PAPOLA, mean_shallow=0.871, mean_deep=1.911
# gene: KLC1, mean_shallow=0.849, mean_deep=2.085
# gene: MTDH, mean_shallow=0.751, mean_deep=1.790
# gene: POLR2K, mean_shallow=0.988, mean_deep=2.326
# gene: MRPL13, mean_shallow=0.517, mean_deep=1.566
# gene: EEF1D, mean_shallow=0.761, mean_deep=1.955
# gene: PUF60, mean_shallow=0.823, mean_deep=2.114
# gene: MAF1, mean_shallow=0.799, mean_deep=2.099
# gene: TONSL, mean_shallow=0.879, mean_deep=2.207
# gene: TXN2, mean_shallow=0.836, mean_deep=2.321
# gene: EIF3D, mean_shallow=0.738, mean_deep=2.186
# gene: SH3BP1, mean_shallow=0.784, mean_deep=1.946
# gene: EIF3L, mean_shallow=0.669, mean_deep=2.024
# gene: ATF4, mean_shallow=0.767, mean_deep=1.998
# gene: PHF5A, mean_shallow=0.831, mean_deep=2.066
# gene: ACO2, mean_shallow=0.699, mean_deep=1.751
# gene: SEPT3, mean_shallow=0.989, mean_deep=2.592
# gene: KIF21A, mean_shallow=0.867, mean_deep=1.623
# gene: ZCRB1, mean_shallow=0.980, mean_deep=2.321
# gene: TMBIM6, mean_shallow=0.617, mean_deep=1.544
# gene: COX14, mean_shallow=0.952, mean_deep=2.442
# gene: PAM16, mean_shallow=0.628, mean_deep=1.638
# gene: SNN, mean_shallow=0.782, mean_deep=1.846
# gene: RSL1D1, mean_shallow=0.829, mean_deep=1.672
# gene: NTAN1, mean_shallow=0.723, mean_deep=1.983
# gene: UBE2L3, mean_shallow=0.898, mean_deep=2.779
# gene: DGCR6, mean_shallow=0.681, mean_deep=1.718
# gene: PSMD2, mean_shallow=0.716, mean_deep=1.592
# gene: 0610012G03RIK, mean_shallow=0.921, mean_deep=2.183
# gene: FAM162A, mean_shallow=0.511, mean_deep=1.501
# gene: ROBO2, mean_shallow=0.950, mean_deep=1.701
# gene: SOD1, mean_shallow=0.648, mean_deep=1.770
# gene: CBR1, mean_shallow=0.627, mean_deep=1.747
# gene: EZR, mean_shallow=0.698, mean_deep=1.760
# gene: MRPL18, mean_shallow=0.816, mean_deep=1.940
# gene: ACAT2, mean_shallow=0.993, mean_deep=2.291
# gene: PPP2R1A, mean_shallow=0.943, mean_deep=2.512
# gene: HCFC1R1, mean_shallow=0.808, mean_deep=1.849
# gene: RNPS1, mean_shallow=0.834, mean_deep=1.808
# gene: STUB1, mean_shallow=0.897, mean_deep=2.221
# gene: MRPL28, mean_shallow=0.780, mean_deep=2.016
# gene: ATP6V0E, mean_shallow=0.871, mean_deep=2.318
# gene: CUTA, mean_shallow=0.698, mean_deep=1.772
# gene: BRD2, mean_shallow=0.606, mean_deep=1.683
# gene: RNF5, mean_shallow=0.630, mean_deep=1.742
# gene: CSNK2B, mean_shallow=0.858, mean_deep=2.177
# gene: PPP1R11, mean_shallow=0.765, mean_deep=2.091
# gene: MEA1, mean_shallow=0.553, mean_deep=1.580
# gene: MPND, mean_shallow=0.823, mean_deep=1.846
# gene: CLPP, mean_shallow=0.600, mean_deep=1.522
# gene: DPY30, mean_shallow=0.837, mean_deep=2.197
# gene: RAB18, mean_shallow=0.918, mean_deep=1.657
# gene: CELF4, mean_shallow=0.951, mean_deep=1.719
# gene: HSPA9, mean_shallow=0.745, mean_deep=1.527
# gene: PFDN1, mean_shallow=0.982, mean_deep=2.226
# gene: PHAX, mean_shallow=0.742, mean_deep=1.715
# gene: LMNB1, mean_shallow=0.870, mean_deep=1.913
# gene: TXNL1, mean_shallow=0.935, mean_deep=2.167
# gene: IER3IP1, mean_shallow=0.860, mean_deep=1.908
# gene: RNF165, mean_shallow=0.683, mean_deep=1.643
# gene: TXNL4A, mean_shallow=0.728, mean_deep=1.875
# gene: CYB5A, mean_shallow=0.899, mean_deep=2.182
# gene: MRPL21, mean_shallow=0.539, mean_deep=1.572
# gene: NDUFV1, mean_shallow=0.604, mean_deep=1.690
# gene: MRPL11, mean_shallow=0.742, mean_deep=1.750
# gene: BANF1, mean_shallow=0.992, mean_deep=2.474
# gene: DRAP1, mean_shallow=0.622, mean_deep=2.331
# gene: PPP1R14B, mean_shallow=0.965, mean_deep=2.303
# gene: STIP1, mean_shallow=0.587, mean_deep=1.650
# gene: RCOR2, mean_shallow=0.511, mean_deep=1.630
# gene: POLR2G, mean_shallow=0.689, mean_deep=1.742
# gene: PRPF19, mean_shallow=0.808, mean_deep=2.042
# gene: GM9493, mean_shallow=0.541, mean_deep=2.310
# gene: PLGRKT, mean_shallow=0.699, mean_deep=1.692
# gene: MARCH5, mean_shallow=0.732, mean_deep=1.761
# gene: MRPL43, mean_shallow=0.593, mean_deep=1.545
# gene: ACTR1A, mean_shallow=0.663, mean_deep=1.562
# gene: INA, mean_shallow=0.714, mean_deep=1.681
# gene: BBIP1, mean_shallow=0.852, mean_deep=2.182
# gene: RPS12-PS3, mean_shallow=0.208, mean_deep=2.287

# %%
sd.fig_xx_cv(M[d_deep][idx_deep,:],M_ml[d_deep][idx_deep,:],
             M[d_shallow][idx_shallow,:],M_ml[d_shallow][idx_shallow,:],
             gene_list_,gene_list_,['deep','shallow'],mean_fil=0,s=None,margin=0.1)
# Out:
# ml: above=374, below=0, avg_r log10(cv2/cv1)=0.166
# dd: above=238, below=136, avg_r log10(cv2/cv1)=0.040

# %% [markdown]
# ### try another two...

# %%
d_deep = 'brain1k'
d_shallow = 'brain9k'
gene_list_ = []
idx_deep = []
idx_shallow = []

for gene in gene_list[d_deep]:   
    if (gene.upper() in gene_list[d_deep]) and (gene.upper() in gene_list[d_shallow]):
        temp_deep = gene_list[d_deep].index(gene.upper())
        temp_shallow = gene_list[d_shallow].index(gene.upper())
    else: 
        continue
    if (M_ml_nsf[d_shallow][temp_shallow,0]<1.5) and (M_ml_nsf[d_deep][temp_deep,0]>2):
        gene_list_.append(gene)
        idx_deep.append(temp_deep)
        idx_shallow.append(temp_shallow)
        print('gene: %s, mean_shallow=%0.3f, mean_deep=%0.3f'
              %(gene,M_ml_nsf[d_shallow][temp_shallow,0],
                M[d_deep][temp_deep,0]))
# Out:
# gene: SNHG6, mean_shallow=0.919, mean_deep=2.009
# gene: EIF5B, mean_shallow=1.450, mean_deep=2.348
# gene: NDUFB3, mean_shallow=1.489, mean_deep=2.643
# gene: IGFBP2, mean_shallow=1.379, mean_deep=2.267
# gene: HES6, mean_shallow=1.464, mean_deep=2.841
# gene: NDUFA10, mean_shallow=1.426, mean_deep=2.551
# gene: NUCKS1, mean_shallow=1.119, mean_deep=2.016
# gene: CNTN2, mean_shallow=1.114, mean_deep=2.544
# gene: BTG2, mean_shallow=0.773, mean_deep=2.076
# gene: GLRX2, mean_shallow=1.085, mean_deep=2.034
# gene: MRPS14, mean_shallow=1.158, mean_deep=2.014
# gene: NDUFS2, mean_shallow=1.364, mean_deep=2.504
# gene: IGSF8, mean_shallow=1.020, mean_deep=2.075
# gene: FRMD4A, mean_shallow=1.293, mean_deep=2.176
# gene: NPDC1, mean_shallow=1.434, mean_deep=2.431
# gene: PSMD14, mean_shallow=1.366, mean_deep=2.214
# gene: ZC3H15, mean_shallow=1.275, mean_deep=2.350
# gene: SSRP1, mean_shallow=1.273, mean_deep=2.356
# gene: NDUFS3, mean_shallow=1.337, mean_deep=2.361
# gene: PSMC3, mean_shallow=1.133, mean_deep=2.085
# gene: CCDC34, mean_shallow=1.244, mean_deep=2.516
# gene: SCG5, mean_shallow=1.480, mean_deep=2.252
# gene: DUT, mean_shallow=1.179, mean_deep=2.293
# gene: EID1, mean_shallow=1.380, mean_deep=2.417
# gene: ERGIC3, mean_shallow=1.344, mean_deep=2.042
# gene: SCAND1, mean_shallow=1.461, mean_deep=2.598
# gene: DLGAP4, mean_shallow=1.320, mean_deep=2.336
# gene: UBE2C, mean_shallow=1.120, mean_deep=2.327
# gene: FAM210B, mean_shallow=1.066, mean_deep=2.189
# gene: NDUFA1, mean_shallow=1.337, mean_deep=2.217
# gene: BEX4, mean_shallow=1.454, mean_deep=2.201
# gene: BEX1, mean_shallow=1.351, mean_deep=2.193
# gene: EIF1AX, mean_shallow=1.491, mean_deep=2.624
# gene: SEC62, mean_shallow=1.497, mean_deep=2.090
# gene: MEX3A, mean_shallow=0.917, mean_deep=2.001
# gene: LAMTOR2, mean_shallow=1.418, mean_deep=2.324
# gene: SSR2, mean_shallow=1.379, mean_deep=2.148
# gene: VPS72, mean_shallow=1.171, mean_deep=2.263
# gene: MRPS21, mean_shallow=1.414, mean_deep=2.403
# gene: ANP32E, mean_shallow=1.456, mean_deep=2.150
# gene: LAMTOR5, mean_shallow=1.496, mean_deep=2.545
# gene: GSTM5, mean_shallow=1.277, mean_deep=2.125
# gene: SARS, mean_shallow=1.286, mean_deep=2.055
# gene: 1810037I17RIK, mean_shallow=1.367, mean_deep=2.076
# gene: OSTC, mean_shallow=1.416, mean_deep=2.255
# gene: LMO4, mean_shallow=1.406, mean_deep=2.736
# gene: POU3F2, mean_shallow=1.350, mean_deep=2.029
# gene: NDUFB6, mean_shallow=1.494, mean_deep=2.987
# gene: MAGOH, mean_shallow=1.166, mean_deep=2.017
# gene: NASP, mean_shallow=1.288, mean_deep=2.478
# gene: RBBP4, mean_shallow=1.346, mean_deep=2.010
# gene: DNAJC8, mean_shallow=1.400, mean_deep=2.525
# gene: MFAP2, mean_shallow=1.295, mean_deep=2.700
# gene: AKAP9, mean_shallow=1.477, mean_deep=2.280
# gene: MED28, mean_shallow=1.400, mean_deep=2.491
# gene: CCNI, mean_shallow=1.498, mean_deep=2.346
# gene: HNRNPD, mean_shallow=1.019, mean_deep=2.940
# gene: ERP29, mean_shallow=1.315, mean_deep=2.191
# gene: MRPS17, mean_shallow=1.158, mean_deep=3.063
# gene: POLR2J, mean_shallow=1.479, mean_deep=2.499
# gene: COPS6, mean_shallow=1.363, mean_deep=2.397
# gene: FAM220A, mean_shallow=1.075, mean_deep=2.243
# gene: BUD31, mean_shallow=1.161, mean_deep=2.071
# gene: EZH2, mean_shallow=1.110, mean_deep=2.380
# gene: SNRNP27, mean_shallow=1.187, mean_deep=2.043
# gene: RAB7, mean_shallow=1.442, mean_deep=2.052
# gene: ZFP637, mean_shallow=1.153, mean_deep=2.229
# gene: ATP6V1E1, mean_shallow=1.465, mean_deep=2.506
# gene: EMG1, mean_shallow=1.321, mean_deep=2.262
# gene: ING4, mean_shallow=1.262, mean_deep=2.121
# gene: TRIM28, mean_shallow=1.431, mean_deep=2.305
# gene: CHMP2A, mean_shallow=1.382, mean_deep=2.351
# gene: GLTSCR2, mean_shallow=1.401, mean_deep=2.554
# gene: SNRPA, mean_shallow=1.237, mean_deep=2.218
# gene: TTC9B, mean_shallow=1.460, mean_deep=2.479
# gene: PSMC4, mean_shallow=1.442, mean_deep=2.988
# gene: FBL, mean_shallow=1.454, mean_deep=2.493
# gene: CLIP3, mean_shallow=1.366, mean_deep=2.319
# gene: PSENEN, mean_shallow=1.258, mean_deep=2.359
# gene: SNRNP70, mean_shallow=1.331, mean_deep=2.685
# gene: IDH2, mean_shallow=1.040, mean_deep=2.071
# gene: EIF3C, mean_shallow=1.292, mean_deep=2.386
# gene: DCTPP1, mean_shallow=1.200, mean_deep=2.295
# gene: BUB3, mean_shallow=1.234, mean_deep=2.434
# gene: MRPL23, mean_shallow=1.410, mean_deep=2.373
# gene: SF3B5, mean_shallow=1.297, mean_deep=2.409
# gene: CITED2, mean_shallow=1.377, mean_deep=2.608
# gene: RWDD1, mean_shallow=1.301, mean_deep=2.323
# gene: PPA1, mean_shallow=1.249, mean_deep=2.380
# gene: R3HDM4, mean_shallow=1.326, mean_deep=2.013
# gene: POLR2E, mean_shallow=1.214, mean_deep=2.125
# gene: NDUFS7, mean_shallow=1.358, mean_deep=2.172
# gene: SGTA, mean_shallow=1.408, mean_deep=2.170
# gene: MRPL42, mean_shallow=1.157, mean_deep=2.089
# gene: PA2G4, mean_shallow=1.367, mean_deep=2.444
# gene: COPE, mean_shallow=1.345, mean_deep=2.400
# gene: CCDC124, mean_shallow=1.309, mean_deep=2.417
# gene: USE1, mean_shallow=1.247, mean_deep=2.277
# gene: MRPL34, mean_shallow=1.249, mean_deep=2.443
# gene: IER2, mean_shallow=0.820, mean_deep=2.472
# gene: POLR2C, mean_shallow=1.168, mean_deep=2.025
# gene: GM8730, mean_shallow=1.220, mean_deep=2.545
# gene: FAM96B, mean_shallow=1.099, mean_deep=2.091
# gene: ATP6V0D1, mean_shallow=1.443, mean_deep=2.292
# gene: APRT, mean_shallow=1.484, mean_deep=2.241
# gene: THOC7, mean_shallow=1.434, mean_deep=2.624
# gene: PSMD6, mean_shallow=1.341, mean_deep=2.357
# gene: UBE2E1, mean_shallow=1.393, mean_deep=2.163
# gene: RPL23A-PS3, mean_shallow=0.667, mean_deep=3.066
# gene: APEX1, mean_shallow=1.374, mean_deep=2.928
# gene: ACIN1, mean_shallow=1.268, mean_deep=2.718
# gene: PSME1, mean_shallow=1.162, mean_deep=2.092
# gene: FDFT1, mean_shallow=1.078, mean_deep=2.032
# gene: UCHL3, mean_shallow=1.327, mean_deep=2.282
# gene: DCUN1D5, mean_shallow=1.300, mean_deep=2.049
# gene: CWC15, mean_shallow=1.350, mean_deep=2.407
# gene: PIN1, mean_shallow=1.189, mean_deep=2.191
# gene: EIF3G, mean_shallow=1.417, mean_deep=2.592
# gene: CDC37, mean_shallow=1.168, mean_deep=2.142
# gene: SMARCA4, mean_shallow=1.207, mean_deep=2.487
# gene: OPCML, mean_shallow=1.410, mean_deep=2.134
# gene: H2AFX, mean_shallow=1.071, mean_deep=2.118
# gene: RDX, mean_shallow=1.325, mean_deep=2.329
# gene: ACAT1, mean_shallow=1.390, mean_deep=2.332
# gene: RNF7, mean_shallow=1.438, mean_deep=2.113
# gene: ANAPC13, mean_shallow=1.300, mean_deep=2.197
# gene: PCBP4, mean_shallow=1.482, mean_deep=2.560
# gene: MRPS24, mean_shallow=1.375, mean_deep=2.389
# gene: RAB1A, mean_shallow=1.403, mean_deep=2.244
# gene: AHSA2, mean_shallow=1.126, mean_deep=2.002
# gene: FAM114A2, mean_shallow=0.958, mean_deep=2.269
# gene: NCOR1, mean_shallow=1.473, mean_deep=2.032
# gene: C1QBP, mean_shallow=1.278, mean_deep=2.169
# gene: PSMD11, mean_shallow=1.300, mean_deep=2.290
# gene: SUPT4A, mean_shallow=1.209, mean_deep=2.150
# gene: DNAJC7, mean_shallow=1.416, mean_deep=2.113
# gene: PSMC5, mean_shallow=1.295, mean_deep=2.473
# gene: FAM195B, mean_shallow=1.419, mean_deep=2.404
# gene: ARHGDIA, mean_shallow=1.494, mean_deep=2.625
# gene: NOL7, mean_shallow=1.439, mean_deep=2.716
# gene: DEK, mean_shallow=1.134, mean_deep=2.655
# gene: CKS2, mean_shallow=1.120, mean_deep=2.389
# gene: GADD45G, mean_shallow=0.853, mean_deep=2.994
# gene: PRELID1, mean_shallow=1.212, mean_deep=2.077
# gene: TMED9, mean_shallow=1.214, mean_deep=2.099
# gene: NSA2, mean_shallow=1.061, mean_deep=2.185
# gene: ODC1, mean_shallow=1.296, mean_deep=2.351
# gene: SRP54B, mean_shallow=1.395, mean_deep=2.017
# gene: SLIRP, mean_shallow=1.243, mean_deep=2.353
# gene: GLRX5, mean_shallow=1.109, mean_deep=2.004
# gene: KLC1, mean_shallow=1.323, mean_deep=2.040
# gene: POLR2K, mean_shallow=1.466, mean_deep=2.338
# gene: EEF1D, mean_shallow=1.310, mean_deep=2.048
# gene: PUF60, mean_shallow=1.342, mean_deep=2.029
# gene: MAF1, mean_shallow=1.154, mean_deep=2.089
# gene: TONSL, mean_shallow=1.312, mean_deep=2.132
# gene: TXN2, mean_shallow=1.321, mean_deep=2.340
# gene: EIF3D, mean_shallow=1.157, mean_deep=2.157
# gene: PHF5A, mean_shallow=1.240, mean_deep=2.060
# gene: SEPT3, mean_shallow=1.462, mean_deep=2.572
# gene: ZCRB1, mean_shallow=1.411, mean_deep=2.362
# gene: COX14, mean_shallow=1.467, mean_deep=2.571
# gene: UBE2L3, mean_shallow=1.390, mean_deep=2.820
# gene: 0610012G03RIK, mean_shallow=1.334, mean_deep=2.229
# gene: STUB1, mean_shallow=1.451, mean_deep=2.293
# gene: MRPL28, mean_shallow=1.208, mean_deep=2.105
# gene: ATP6V0E, mean_shallow=1.400, mean_deep=2.364
# gene: PFDN6, mean_shallow=1.419, mean_deep=2.568
# gene: CSNK2B, mean_shallow=1.429, mean_deep=2.255
# gene: PPP1R11, mean_shallow=1.126, mean_deep=2.117
# gene: DPY30, mean_shallow=1.357, mean_deep=2.266
# gene: KIF5B, mean_shallow=1.460, mean_deep=2.303
# gene: PFDN1, mean_shallow=1.467, mean_deep=2.261
# gene: LMNB1, mean_shallow=1.435, mean_deep=2.004
# gene: TXNL1, mean_shallow=1.462, mean_deep=2.121
# gene: IER3IP1, mean_shallow=1.300, mean_deep=2.039
# gene: DRAP1, mean_shallow=1.002, mean_deep=2.551
# gene: NXF1, mean_shallow=1.351, mean_deep=2.527
# gene: PRPF19, mean_shallow=1.240, mean_deep=2.021
# gene: GM9493, mean_shallow=1.196, mean_deep=2.303
# gene: BBIP1, mean_shallow=1.441, mean_deep=2.249
# gene: RPS12-PS3, mean_shallow=0.462, mean_deep=2.373

# %%
sd.fig_xx_cv(M[d_deep][idx_deep,:],M_ml[d_deep][idx_deep,:],
             M[d_shallow][idx_shallow,:],M_ml[d_shallow][idx_shallow,:],
             gene_list_,gene_list_,['deep','shallow'],mean_fil=0,s=None,margin=0.1)
# Out:
# ml: above=113, below=6, avg_r log10(cv2/cv1)=0.124
# dd: above=67, below=52, avg_r log10(cv2/cv1)=0.003

# %%
d_deep = 'brain1k'
d_shallow = 'brain2k'
gene_list_ = []
idx_deep = []
idx_shallow = []

for gene in gene_list[d_deep]:   
    if (gene.upper() in gene_list[d_deep]) and (gene.upper() in gene_list[d_shallow]):
        temp_deep = gene_list[d_deep].index(gene.upper())
        temp_shallow = gene_list[d_shallow].index(gene.upper())
    else: 
        continue
    if (M_ml_nsf[d_shallow][temp_shallow,0]<1.5) and (M_ml_nsf[d_deep][temp_deep,0]>2):
        gene_list_.append(gene)
        idx_deep.append(temp_deep)
        idx_shallow.append(temp_shallow)
        print('gene: %s, mean_shallow=%0.3f, mean_deep=%0.3f'
              %(gene,M_ml_nsf[d_shallow][temp_shallow,0],
                M[d_deep][temp_deep,0]))
# Out:
# gene: SNHG6, mean_shallow=0.423, mean_deep=2.009
# gene: EIF5B, mean_shallow=1.162, mean_deep=2.348
# gene: POU3F3, mean_shallow=1.493, mean_deep=2.571
# gene: NDUFB3, mean_shallow=1.148, mean_deep=2.643
# gene: IDH1, mean_shallow=1.492, mean_deep=2.061
# gene: IGFBP2, mean_shallow=1.189, mean_deep=2.267
# gene: NUCKS1, mean_shallow=0.857, mean_deep=2.016
# gene: CNTN2, mean_shallow=0.992, mean_deep=2.544
# gene: BTG2, mean_shallow=1.356, mean_deep=2.076
# gene: GLRX2, mean_shallow=1.405, mean_deep=2.034
# gene: MRPS14, mean_shallow=1.409, mean_deep=2.014
# gene: PRDX6, mean_shallow=1.394, mean_deep=2.185
# gene: MPC2, mean_shallow=1.102, mean_deep=2.626
# gene: PBX1, mean_shallow=1.205, mean_deep=3.212
# gene: IGSF8, mean_shallow=1.088, mean_deep=2.075
# gene: ZBTB18, mean_shallow=1.358, mean_deep=2.604
# gene: SRP9, mean_shallow=1.319, mean_deep=2.664
# gene: FRMD4A, mean_shallow=0.906, mean_deep=2.176
# gene: NPDC1, mean_shallow=1.254, mean_deep=2.431
# gene: ZEB2, mean_shallow=0.856, mean_deep=2.291
# gene: DYNC1I2, mean_shallow=1.385, mean_deep=2.534
# gene: ATP5G3, mean_shallow=1.375, mean_deep=3.909
# gene: ZC3H15, mean_shallow=1.192, mean_deep=2.350
# gene: SSRP1, mean_shallow=1.199, mean_deep=2.356
# gene: EIF3M, mean_shallow=1.446, mean_deep=3.377
# gene: MPPED2, mean_shallow=1.401, mean_deep=3.151
# gene: CCDC34, mean_shallow=0.893, mean_deep=2.516
# gene: RTF1, mean_shallow=1.328, mean_deep=3.067
# gene: DUT, mean_shallow=1.357, mean_deep=2.293
# gene: EID1, mean_shallow=0.952, mean_deep=2.417
# gene: DLGAP4, mean_shallow=1.412, mean_deep=2.336
# gene: ZFOS1, mean_shallow=1.131, mean_deep=3.448
# gene: FAM210B, mean_shallow=1.361, mean_deep=2.189
# gene: UBA1, mean_shallow=1.437, mean_deep=2.133
# gene: NDUFA1, mean_shallow=1.199, mean_deep=2.217
# gene: OGT, mean_shallow=0.888, mean_deep=2.076
# gene: XIST, mean_shallow=1.422, mean_deep=10.561
# gene: BEX4, mean_shallow=0.837, mean_deep=2.201
# gene: BEX1, mean_shallow=1.130, mean_deep=2.193
# gene: SEC62, mean_shallow=0.998, mean_deep=2.090
# gene: MEX3A, mean_shallow=0.453, mean_deep=2.001
# gene: SSR2, mean_shallow=1.409, mean_deep=2.148
# gene: SYT11, mean_shallow=1.281, mean_deep=2.681
# gene: VPS72, mean_shallow=1.427, mean_deep=2.263
# gene: CSDE1, mean_shallow=1.035, mean_deep=2.124
# gene: 1810037I17RIK, mean_shallow=1.032, mean_deep=2.076
# gene: OSTC, mean_shallow=1.389, mean_deep=2.255
# gene: LMO4, mean_shallow=1.001, mean_deep=2.736
# gene: POU3F2, mean_shallow=1.099, mean_deep=2.029
# gene: ANP32B, mean_shallow=1.422, mean_deep=2.623
# gene: NFIA, mean_shallow=1.337, mean_deep=2.855
# gene: MAGOH, mean_shallow=1.120, mean_deep=2.017
# gene: NASP, mean_shallow=1.348, mean_deep=2.478
# gene: RBBP4, mean_shallow=1.267, mean_deep=2.010
# gene: CAPZB, mean_shallow=1.284, mean_deep=2.569
# gene: MFAP2, mean_shallow=1.320, mean_deep=2.700
# gene: CTNNBIP1, mean_shallow=1.141, mean_deep=2.342
# gene: AKAP9, mean_shallow=1.241, mean_deep=2.280
# gene: RHEB, mean_shallow=1.485, mean_deep=2.274
# gene: G3BP2, mean_shallow=1.476, mean_deep=2.584
# gene: CCNI, mean_shallow=1.204, mean_deep=2.346
# gene: HNRNPD, mean_shallow=0.646, mean_deep=2.940
# gene: TTC28, mean_shallow=1.367, mean_deep=3.867
# gene: ERP29, mean_shallow=1.259, mean_deep=2.191
# gene: RSRC2, mean_shallow=1.338, mean_deep=2.400
# gene: MRPS17, mean_shallow=1.243, mean_deep=3.063
# gene: AUTS2, mean_shallow=1.212, mean_deep=6.567
# gene: EIF4H, mean_shallow=1.360, mean_deep=2.997
# gene: FAM220A, mean_shallow=1.438, mean_deep=2.243
# gene: ARPC1A, mean_shallow=1.448, mean_deep=2.663
# gene: BUD31, mean_shallow=1.288, mean_deep=2.071
# gene: POLR1D, mean_shallow=1.399, mean_deep=3.352
# gene: EZH2, mean_shallow=1.179, mean_deep=2.380
# gene: TRA2A, mean_shallow=1.110, mean_deep=3.528
# gene: PCBP1, mean_shallow=1.494, mean_deep=2.876
# gene: SNRNP27, mean_shallow=1.331, mean_deep=2.043
# gene: ZFP637, mean_shallow=1.150, mean_deep=2.229
# gene: ATP6V1E1, mean_shallow=1.468, mean_deep=2.506
# gene: EMG1, mean_shallow=1.455, mean_deep=2.262
# gene: ING4, mean_shallow=1.150, mean_deep=2.121
# gene: TRIM28, mean_shallow=1.155, mean_deep=2.305
# gene: SNRPA, mean_shallow=1.418, mean_deep=2.218
# gene: CLIP3, mean_shallow=1.094, mean_deep=2.319
# gene: PSENEN, mean_shallow=1.411, mean_deep=2.359
# gene: SNRNP70, mean_shallow=1.286, mean_deep=2.685
# gene: IDH2, mean_shallow=1.242, mean_deep=2.071
# gene: UQCRC2, mean_shallow=1.353, mean_deep=2.780
# gene: EIF3C, mean_shallow=1.250, mean_deep=2.386
# gene: BUB3, mean_shallow=1.419, mean_deep=2.434
# gene: SF3B5, mean_shallow=1.289, mean_deep=2.409
# gene: CITED2, mean_shallow=0.997, mean_deep=2.608
# gene: RWDD1, mean_shallow=1.093, mean_deep=2.323
# gene: PPA1, mean_shallow=1.269, mean_deep=2.380
# gene: R3HDM4, mean_shallow=1.187, mean_deep=2.013
# gene: POLR2E, mean_shallow=1.414, mean_deep=2.125
# gene: MAP2K2, mean_shallow=1.400, mean_deep=2.517
# gene: MRPL42, mean_shallow=1.485, mean_deep=2.089
# gene: CSRP2, mean_shallow=1.168, mean_deep=2.921
# gene: PA2G4, mean_shallow=1.159, mean_deep=2.444
# gene: CTXN1, mean_shallow=1.004, mean_deep=3.528
# gene: USE1, mean_shallow=1.183, mean_deep=2.277
# gene: MRPL34, mean_shallow=1.472, mean_deep=2.443
# gene: RBMXL1, mean_shallow=1.283, mean_deep=2.531
# gene: POLR2C, mean_shallow=1.394, mean_deep=2.025
# gene: FAM96B, mean_shallow=1.187, mean_deep=2.091
# gene: TCF25, mean_shallow=1.150, mean_deep=2.299
# gene: THOC7, mean_shallow=1.212, mean_deep=2.624
# gene: UBE2E1, mean_shallow=1.290, mean_deep=2.163
# gene: NISCH, mean_shallow=1.213, mean_deep=2.088
# gene: ACIN1, mean_shallow=1.248, mean_deep=2.718
# gene: PSME1, mean_shallow=1.201, mean_deep=2.092
# gene: FDFT1, mean_shallow=0.949, mean_deep=2.032
# gene: UCHL3, mean_shallow=1.497, mean_deep=2.282
# gene: DCUN1D5, mean_shallow=1.478, mean_deep=2.049
# gene: CWC15, mean_shallow=1.037, mean_deep=2.407
# gene: SMARCA4, mean_shallow=1.243, mean_deep=2.487
# gene: OPCML, mean_shallow=0.725, mean_deep=2.134
# gene: H2AFX, mean_shallow=1.179, mean_deep=2.118
# gene: RDX, mean_shallow=1.005, mean_deep=2.329
# gene: ACAT1, mean_shallow=1.202, mean_deep=2.332
# gene: NEDD4, mean_shallow=1.414, mean_deep=2.493
# gene: RNF7, mean_shallow=1.192, mean_deep=2.113
# gene: MANF, mean_shallow=1.390, mean_deep=2.996
# gene: GNAI2, mean_shallow=1.159, mean_deep=3.270
# gene: RAB1A, mean_shallow=1.261, mean_deep=2.244
# gene: AHSA2, mean_shallow=1.196, mean_deep=2.002
# gene: FAM114A2, mean_shallow=0.829, mean_deep=2.269
# gene: NCOR1, mean_shallow=1.335, mean_deep=2.032
# gene: C1QBP, mean_shallow=1.284, mean_deep=2.169
# gene: ZFP207, mean_shallow=1.194, mean_deep=2.201
# gene: PSMD11, mean_shallow=1.342, mean_deep=2.290
# gene: SRSF1, mean_shallow=1.263, mean_deep=2.203
# gene: LUC7L3, mean_shallow=1.182, mean_deep=2.934
# gene: RALA, mean_shallow=1.212, mean_deep=3.197
# gene: NOL7, mean_shallow=1.181, mean_deep=2.716
# gene: DEK, mean_shallow=0.897, mean_deep=2.655
# gene: CKS2, mean_shallow=1.239, mean_deep=2.389
# gene: PRELID1, mean_shallow=1.428, mean_deep=2.077
# gene: TMED9, mean_shallow=1.373, mean_deep=2.099
# gene: NR2F1, mean_shallow=1.118, mean_deep=2.951
# gene: NSA2, mean_shallow=0.883, mean_deep=2.185
# gene: ODC1, mean_shallow=0.916, mean_deep=2.351
# gene: FOXG1, mean_shallow=1.443, mean_deep=3.880
# gene: SRP54B, mean_shallow=1.291, mean_deep=2.017
# gene: SRSF5, mean_shallow=1.408, mean_deep=3.229
# gene: SLIRP, mean_shallow=1.324, mean_deep=2.353
# gene: GLRX5, mean_shallow=1.470, mean_deep=2.004
# gene: KLC1, mean_shallow=1.355, mean_deep=2.040
# gene: YWHAZ, mean_shallow=1.189, mean_deep=2.651
# gene: MAF1, mean_shallow=1.440, mean_deep=2.089
# gene: RBFOX2, mean_shallow=0.855, mean_deep=2.829
# gene: TXN2, mean_shallow=1.485, mean_deep=2.340
# gene: EIF3D, mean_shallow=1.213, mean_deep=2.157
# gene: CSNK1E, mean_shallow=1.153, mean_deep=3.153
# gene: ST13, mean_shallow=1.450, mean_deep=2.456
# gene: SEPT3, mean_shallow=1.050, mean_deep=2.572
# gene: ZCRB1, mean_shallow=1.322, mean_deep=2.362
# gene: UBE2L3, mean_shallow=1.448, mean_deep=2.820
# gene: PPP2R1A, mean_shallow=1.422, mean_deep=2.489
# gene: CSNK2B, mean_shallow=1.266, mean_deep=2.255
# gene: MYL12B, mean_shallow=1.114, mean_deep=3.056
# gene: DPY30, mean_shallow=1.443, mean_deep=2.266
# gene: KIF5B, mean_shallow=1.471, mean_deep=2.303
# gene: LMNB1, mean_shallow=1.469, mean_deep=2.004
# gene: TXNL1, mean_shallow=1.380, mean_deep=2.121
# gene: IER3IP1, mean_shallow=1.270, mean_deep=2.039
# gene: CYB5A, mean_shallow=1.407, mean_deep=2.315
# gene: DRAP1, mean_shallow=0.988, mean_deep=2.551
# gene: PRPF19, mean_shallow=1.076, mean_deep=2.021
# gene: GM9493, mean_shallow=1.331, mean_deep=2.303
# gene: BBIP1, mean_shallow=1.166, mean_deep=2.249
# gene: RPS12-PS3, mean_shallow=0.612, mean_deep=2.373
# gene: MT-ND3, mean_shallow=1.333, mean_deep=3.566

# %%
sd.fig_xx_cv(M[d_deep][idx_deep,:],M_ml[d_deep][idx_deep,:],
             M[d_shallow][idx_shallow,:],M_ml[d_shallow][idx_shallow,:],
             gene_list_,gene_list_,['deep','shallow'],mean_fil=0,s=None,margin=0.1)
# Out:
# ml: above=85, below=14, avg_r log10(cv2/cv1)=0.098
# dd: above=23, below=76, avg_r log10(cv2/cv1)=-0.156

# %%
d_deep = 'brain2k'
d_shallow = 'brain1k'
gene_list_ = []
idx_deep = []
idx_shallow = []

for gene in gene_list[d_deep]:   
    if (gene.upper() in gene_list[d_deep]) and (gene.upper() in gene_list[d_shallow]):
        temp_deep = gene_list[d_deep].index(gene.upper())
        temp_shallow = gene_list[d_shallow].index(gene.upper())
    else: 
        continue
    if (M_ml_nsf[d_shallow][temp_shallow,0]<1) and (M_ml_nsf[d_deep][temp_deep,0]>1.5):
        gene_list_.append(gene)
        idx_deep.append(temp_deep)
        idx_shallow.append(temp_shallow)
        print('gene: %s, mean_shallow=%0.3f, mean_deep=%0.3f'
              %(gene,M_ml_nsf[d_shallow][temp_shallow,0],
                M[d_deep][temp_deep,0]))
# Out:
# gene: GRCC10, mean_shallow=0.852, mean_deep=1.800
# gene: APOE, mean_shallow=0.814, mean_deep=2.068
# gene: GM10116, mean_shallow=0.243, mean_deep=2.397
# gene: MT-ATP8, mean_shallow=0.643, mean_deep=2.412

# %%
sd.fig_xx_cv(M[d_deep][idx_deep,:],M_ml[d_deep][idx_deep,:],
             M[d_shallow][idx_shallow,:],M_ml[d_shallow][idx_shallow,:],
             gene_list_,gene_list_,['deep','shallow'],mean_fil=0,s=100,margin=0.1)
# Out:
# ml: above=3, below=0, avg_r log10(cv2/cv1)=0.221
# dd: above=2, below=1, avg_r log10(cv2/cv1)=0.033

# %%
d_deep = 'PBMC8k'
d_shallow = 'PBMC68k'
gene_list_ = []
idx_deep = []
idx_shallow = []
data_deep = dataset[d_deep].copy()
sc.pp.filter_genes(data_deep,min_counts=2*data_deep.shape[0])

for gene in data_deep.var_names: 
    if (gene.upper() in gene_list[d_deep]) and (gene.upper() in gene_list[d_shallow]):
        temp_deep = gene_list[d_deep].index(gene.upper())
        temp_shallow = gene_list[d_shallow].index(gene.upper())
    else: 
        continue
    if M_ml_nsf[d_shallow][temp_shallow,0]<2:
        gene_list_.append(gene)
        idx_deep.append(temp_deep)
        idx_shallow.append(temp_shallow)
        print('gene: %s, mean_shallow=%0.3f, mean_deep=%0.3f'
              %(gene,M_ml_nsf[d_shallow][temp_shallow,0],
                M[d_deep][temp_deep,0]))
# Out:
# gene: RPL22, mean_shallow=1.345, mean_deep=9.018
# gene: CDC42, mean_shallow=0.151, mean_deep=2.247
# gene: LAPTM5, mean_shallow=0.617, mean_deep=3.061
# gene: YBX1, mean_shallow=1.445, mean_deep=3.569
# gene: JUN, mean_shallow=1.243, mean_deep=5.684
# gene: TXNIP, mean_shallow=0.890, mean_deep=3.033
# gene: CTSS, mean_shallow=0.337, mean_deep=4.464
# gene: S100A10, mean_shallow=0.860, mean_deep=2.599
# gene: S100A11, mean_shallow=0.402, mean_deep=2.592
# gene: S100A9, mean_shallow=0.299, mean_deep=16.659
# gene: S100A8, mean_shallow=0.208, mean_deep=13.682
# gene: S100A6, mean_shallow=1.513, mean_deep=9.360
# gene: FCER1G, mean_shallow=0.435, mean_deep=2.880
# gene: PTPRC, mean_shallow=0.403, mean_deep=2.643
# gene: H3F3A, mean_shallow=0.131, mean_deep=5.891
# gene: OST4, mean_shallow=0.576, mean_deep=2.357
# gene: ZFP36L2, mean_shallow=0.610, mean_deep=2.881
# gene: CALM2, mean_shallow=0.509, mean_deep=2.672
# gene: CXCR4, mean_shallow=0.377, mean_deep=2.074
# gene: NBEAL1, mean_shallow=0.375, mean_deep=2.944
# gene: ARPC2, mean_shallow=1.122, mean_deep=3.092
# gene: TMA7, mean_shallow=0.812, mean_deep=3.395
# gene: GPX1, mean_shallow=0.458, mean_deep=2.677
# gene: CCNI, mean_shallow=0.555, mean_deep=2.390
# gene: BTF3, mean_shallow=1.890, mean_deep=4.831
# gene: COX7C, mean_shallow=0.719, mean_deep=4.189
# gene: HINT1, mean_shallow=0.917, mean_deep=2.938
# gene: NPM1, mean_shallow=1.790, mean_deep=4.319
# gene: DUSP1, mean_shallow=0.839, mean_deep=6.708
# gene: HLA-E, mean_shallow=1.762, mean_deep=4.321
# gene: LST1, mean_shallow=0.430, mean_deep=2.915
# gene: AIF1, mean_shallow=0.524, mean_deep=2.747
# gene: HLA-DRA, mean_shallow=1.322, mean_deep=11.950
# gene: HLA-DRB1, mean_shallow=1.079, mean_deep=6.581
# gene: HLA-DQA1, mean_shallow=0.330, mean_deep=2.156
# gene: HLA-DQB1, mean_shallow=0.261, mean_deep=3.121
# gene: HLA-DPA1, mean_shallow=0.778, mean_deep=4.496
# gene: HLA-DPB1, mean_shallow=0.923, mean_deep=4.795
# gene: PNRC1, mean_shallow=0.698, mean_deep=2.429
# gene: TOMM7, mean_shallow=0.878, mean_deep=3.855
# gene: HNRNPA2B1, mean_shallow=0.836, mean_deep=2.196
# gene: PPIA, mean_shallow=0.864, mean_deep=2.792
# gene: ARPC1B, mean_shallow=1.071, mean_deep=2.610
# gene: SLC25A6, mean_shallow=1.860, mean_deep=4.380
# gene: SAT1, mean_shallow=0.564, mean_deep=3.938
# gene: RPL36A, mean_shallow=1.679, mean_deep=6.496
# gene: TSC22D3, mean_shallow=0.526, mean_deep=2.310
# gene: RPL39, mean_shallow=0.180, mean_deep=34.869
# gene: UQCRB, mean_shallow=0.123, mean_deep=4.289
# gene: PABPC1, mean_shallow=1.631, mean_deep=6.844
# gene: EIF3E, mean_shallow=0.363, mean_deep=3.078
# gene: FCN1, mean_shallow=0.144, mean_deep=2.175
# gene: NEAT1, mean_shallow=0.167, mean_deep=3.360
# gene: GSTP1, mean_shallow=0.580, mean_deep=2.218
# gene: CD3D, mean_shallow=1.346, mean_deep=2.040
# gene: ATP5L, mean_shallow=1.006, mean_deep=3.718
# gene: HSPA8, mean_shallow=0.889, mean_deep=2.290
# gene: KLF6, mean_shallow=0.326, mean_deep=2.409
# gene: VIM, mean_shallow=1.400, mean_deep=4.921
# gene: SRGN, mean_shallow=0.580, mean_deep=2.850
# gene: PSAP, mean_shallow=0.339, mean_deep=2.698
# gene: GAPDH, mean_shallow=1.761, mean_deep=5.331
# gene: LDHB, mean_shallow=1.734, mean_deep=2.553
# gene: ATP5G2, mean_shallow=1.285, mean_deep=3.302
# gene: HNRNPA1, mean_shallow=1.889, mean_deep=5.984
# gene: RPL41, mean_shallow=0.920, mean_deep=44.958
# gene: MYL6, mean_shallow=1.661, mean_deep=4.293
# gene: LYZ, mean_shallow=0.477, mean_deep=17.511
# gene: NAP1L1, mean_shallow=0.582, mean_deep=2.409
# gene: ARPC3, mean_shallow=1.090, mean_deep=2.910
# gene: UBC, mean_shallow=1.771, mean_deep=4.524
# gene: HMGB1, mean_shallow=0.753, mean_deep=2.310
# gene: ITM2B, mean_shallow=1.279, mean_deep=3.541
# gene: COMMD6, mean_shallow=0.754, mean_deep=2.881
# gene: PSME1, mean_shallow=1.046, mean_deep=2.012
# gene: RPS29, mean_shallow=1.455, mean_deep=35.196
# gene: RPL36AL, mean_shallow=1.347, mean_deep=2.871
# gene: SRSF5, mean_shallow=0.877, mean_deep=2.641
# gene: FOS, mean_shallow=0.657, mean_deep=11.692
# gene: CALM1, mean_shallow=1.087, mean_deep=2.188
# gene: C14orf2, mean_shallow=0.114, mean_deep=2.231
# gene: SRP14, mean_shallow=1.028, mean_deep=2.665
# gene: SERF2, mean_shallow=1.754, mean_deep=5.788
# gene: RPS17, mean_shallow=0.020, mean_deep=13.262
# gene: ALDOA, mean_shallow=0.730, mean_deep=2.591
# gene: CORO1A, mean_shallow=1.741, mean_deep=4.326
# gene: COTL1, mean_shallow=0.738, mean_deep=3.390
# gene: UBB, mean_shallow=1.649, mean_deep=2.858
# gene: RPL23, mean_shallow=1.298, mean_deep=7.071
# gene: LIMD2, mean_shallow=1.154, mean_deep=2.491
# gene: DDX5, mean_shallow=1.408, mean_deep=4.736
# gene: RPL38, mean_shallow=1.322, mean_deep=11.308
# gene: SUMO2, mean_shallow=0.467, mean_deep=2.036
# gene: MYL12A, mean_shallow=1.913, mean_deep=4.290
# gene: RPL17, mean_shallow=1.771, mean_deep=4.113
# gene: CST3, mean_shallow=0.694, mean_deep=7.002
# gene: ATP5E, mean_shallow=1.000, mean_deep=6.104
# gene: RPS21, mean_shallow=1.454, mean_deep=9.905
# gene: PPDPF, mean_shallow=1.018, mean_deep=2.605
# gene: CIRBP, mean_shallow=0.884, mean_deep=2.249
# gene: UQCR11, mean_shallow=0.579, mean_deep=2.044
# gene: EEF2, mean_shallow=1.464, mean_deep=6.024
# gene: IER2, mean_shallow=1.475, mean_deep=2.342
# gene: FXYD5, mean_shallow=1.673, mean_deep=2.621
# gene: COX6B1, mean_shallow=0.520, mean_deep=2.044
# gene: HCST, mean_shallow=0.804, mean_deep=2.448
# gene: TYROBP, mean_shallow=0.671, mean_deep=5.310
# gene: EIF3K, mean_shallow=1.226, mean_deep=2.109
# gene: GMFG, mean_shallow=0.942, mean_deep=2.215
# gene: ZFP36, mean_shallow=0.547, mean_deep=2.819
# gene: SNRPD2, mean_shallow=0.738, mean_deep=2.013
# gene: EMP3, mean_shallow=1.021, mean_deep=2.571
# gene: CD37, mean_shallow=1.159, mean_deep=3.161
# gene: LGALS1, mean_shallow=0.544, mean_deep=3.407
# gene: ITGB2, mean_shallow=0.504, mean_deep=2.195
# gene: MT-ND1, mean_shallow=1.976, mean_deep=7.140
# gene: MT-ND2, mean_shallow=1.636, mean_deep=11.174
# gene: MT-ATP6, mean_shallow=0.928, mean_deep=9.372
# gene: MT-ND3, mean_shallow=0.114, mean_deep=10.596
# gene: MT-ND5, mean_shallow=0.575, mean_deep=5.354

# %%
sd.fig_xx_cv(M[d_deep][idx_deep,:],M_ml[d_deep][idx_deep,:],
             M[d_shallow][idx_shallow,:],M_ml[d_shallow][idx_shallow,:],
             gene_list_,gene_list_,['deep','shallow'],mean_fil=0,s=None,margin=0.1)
# Out:
# ml: above=108, below=3, avg_r log10(cv2/cv1)=0.272
# dd: above=87, below=24, avg_r log10(cv2/cv1)=0.169

# %% [markdown]
# # behaviours of low count genes

# %%
X = dataset['brain1k'].copy().X
Nrc = np.array(X.sum(axis=1),dtype=int)
Nr = Nrc.mean()
g_ml = Nrc/Nr
print('ml',(g_ml**2).mean())
print('dd',((Nrc**2).mean()-Nrc.mean())/Nr**2)
# Out:
# ml 1.6218973700339285
# dd 1.621810551688494

# %%
data_9k = dataset['brain9k'].copy()
sf_9k = sd.sf(data_9k,verbose=True)
sc.pp.filter_genes(data_9k,min_counts=1*data_9k.shape[0])
M_9k,M_ml_9k,gene_list_9k = sd.dd_moment_anndata(data_9k,gamma_c=sf_9k,verbose=True)
# Out:
# Nr=7332
# gamma_c [0.3020941  0.3020941  0.30361167 3.06614736 5.08897634 7.90790987]
# #time start: 0.0s
# n_cell=9128, n_gene=1188
# M1, sf=1.0000
# M2, sf=1.3507
# #time total: 0.6886s

# %%
data_2k = dataset['brain2k'].copy()
sf_2k = sd.sf(data_2k,verbose=True)
sc.pp.filter_genes(data_2k,min_counts=1*data_2k.shape[0])
M_2k,M_ml_2k,gene_list_2k = sd.dd_moment_anndata(data_2k,gamma_c=sf_2k,verbose=True)
# Out:
# Nr=7590
# gamma_c [0.29522318 0.29562254 0.29734204 2.87913475 5.29541401 5.88101435]
# #time start: 0.0s
# n_cell=2022, n_gene=1207
# M1, sf=1.0000
# M2, sf=1.3109
# #time total: 0.3809s

# %%
data_1k = dataset['brain1k'].copy()
sf_1k = sd.sf(data_1k,verbose=True)
sc.pp.filter_genes(data_1k,min_counts=1*data_1k.shape[0])
M_1k,M_ml_1k,gene_list_1k = sd.dd_moment_anndata(data_1k,gamma_c=sf_1k,verbose=True)
# Out:
# Nr=11518
# gamma_c [0.34015429 0.34018659 0.34047724 4.38291998 6.16407987 7.50292826]
# #time start: 0.0s
# n_cell=931, n_gene=1770
# M1, sf=1.0000
# M2, sf=1.6219
# #time total: 0.3454s

# %%
plt.figure(figsize=[18,5])
bins=np.arange(10)
plt.hist(sf_9k,weights=1/sf_9k.shape[0]*np.ones([sf_9k.shape[0]]),alpha=0.5,bins=bins,label='9k')
plt.hist(sf_1k,weights=1/sf_1k.shape[0]*np.ones([sf_1k.shape[0]]),alpha=0.5,bins=bins,label='1k')
plt.legend()
plt.show()

# %%
M1,M2 = M_9k[:,0],M_9k[:,1]
idx_M20 = np.where(M2==0)[0]
gene_M20 = list(data_9k.var_names[idx_M20])
cts_Farp2 = np.array((data_9k[:,'Farp2'].X),dtype=int)

# %%
cts_Farp2_ = np.array((data_1k[:,'Farp2'].X),dtype=int)

# %%
sd.fig_xx_cv(M_9k,M_ml_9k,M_1k,M_ml_1k,gene_list_9k,gene_list_1k,['9k','1k'],mean_fil=0)
# Out:
# ml: above=173, below=1000, avg_r log10(cv2/cv1)=-0.127
# dd: above=460, below=632, avg_r log10(cv2/cv1)=-0.111

# %%
M,M_ml,M_nsf,M_ml_nsf,gene_list,gene_list_nsf = {},{},{},{},{},{}

for dname in dataset.keys():
    if dname=='brain1.3m': break
    print('## processing %s ...'%dname)
    print('# n_cell=%d, n_gene=%d'%(dataset[dname].shape[0],dataset[dname].shape[1]))
    temp = dataset[dname].copy()
    sc.pp.filter_cells(temp, min_counts=0.01*temp.shape[1])
    gamma_c = sd.sf(temp,verbose=False)
    sc.pp.filter_genes(temp,min_counts=0.01*temp.shape[0])
    print('# after filtering: n_cell=%d, n_gene=%d'%(temp.shape[0],temp.shape[1]))
    M_,M_ml_,gene_list_ = sd.dd_moment_anndata(temp,gamma_c=gamma_c,verbose=False)
    M_nsf_,M_ml_nsf_,gene_list_nsf_ = sd.dd_moment_anndata(temp,gamma_c=None,verbose=False)
    
    M[dname],M_ml[dname],M_nsf[dname],M_ml_nsf[dname],gene_list[dname],gene_list_nsf[dname] = \
    M_,M_ml_,M_nsf_,M_ml_nsf_,gene_list_,gene_list_nsf_
    print('\n')
#     if dname=='PBMC8k': break

# %% [markdown]
# # subsample experiment

# %%
## subsampling experiment 
d1 = dataset['brain9k']
sc.pp.filter_cells(d1,min_counts=0.01*d1.shape[1])
sf1 = sd.sf(d1,verbose=False)
sc.pp.filter_genes(d1,min_counts=0.01*d1.shape[0])

d2 = dataset['brain1k']
sc.pp.filter_cells(d2,min_counts=0.01*d2.shape[1])
sf2 = sd.sf(d2,verbose=False)
sc.pp.filter_genes(d2,min_counts=0.01*d2.shape[0])

# %%
d2.n_vars
# Out:
# 12343

# %%
d2.obs
# Out:
#                     n_counts
# AAACCTGGTCTCGTTC-1    9419.0
# AAACGGGAGCCACGTC-1    5717.0
# AAACGGGAGCGAGAAA-1    5189.0
# AAACGGGCACACCGAC-1   13760.0
# AAACGGGTCGCCAGCA-1   15808.0
# AAACGGGTCGCGTTTC-1    7927.0
# AAACGGGTCGGCGGTT-1   12496.0
# AAAGATGAGGCTCAGA-1   10766.0
# AAAGTAGGTACAGACG-1    6417.0
# AAAGTAGGTTGGACCC-1    7341.0
# AAATGCCCAGATTGCT-1    4679.0
# AAATGCCTCATTTGGG-1   25311.0
# AACACGTCACTTCGAA-1    6560.0
# AACACGTGTTTGACTG-1    9633.0
# AACACGTTCTTACCGC-1    5722.0
# AACCATGCAAGCCGTC-1    7315.0
# AACCATGCAGATGGGT-1    4826.0
# AACCGCGAGTCGAGTG-1    7167.0
# AACGTTGAGGCAATTA-1    4420.0
# AACGTTGAGGGCTCTC-1    4102.0
# AACGTTGAGTCATCCA-1    4500.0
# AACGTTGAGTGCAAGC-1    5315.0
# AACGTTGCATTCTTAC-1   34942.0
# AACGTTGGTACGCACC-1    8027.0
# AACTCAGAGGCAGTCA-1   13238.0
# AACTCAGCAAGCTGAG-1   25785.0
# AACTCAGCATACAGCT-1    7915.0
# AACTCAGGTAGAGTGC-1    6750.0
# AACTCAGGTCTAGTCA-1    6600.0
# AACTCAGGTGAGGGAG-1   11717.0
# ...                      ...
# TTCTACAGTTGGTGGA-1    7243.0
# TTCTCAAAGTACACCT-1    7554.0
# TTCTCCTAGATAGGAG-1    7924.0
# TTCTCCTAGTTATCGC-1    8105.0
# TTCTCCTCACACCGCA-1    5125.0
# TTCTTAGCAAACGTGG-1   10421.0
# TTCTTAGCACATTAGC-1   12285.0
# TTCTTAGGTGAAGGCT-1   69934.0
# TTCTTAGTCCTTAATC-1    4490.0
# TTGAACGGTAAAGTCA-1    7666.0
# TTGAACGGTATAGTAG-1    7717.0
# TTGACTTAGATGGCGT-1   13704.0
# TTGACTTAGCGCTCCA-1   21686.0
# TTGCCGTAGTCTCGGC-1    4225.0
# TTGCGTCCAATCACAC-1    8747.0
# TTGCGTCCAGCTCCGA-1   27782.0
# TTGCGTCCATCAGTAC-1    9200.0
# TTGGCAAGTATCAGTC-1    4478.0
# TTGGCAAGTTAAGGGC-1   16345.0
# TTGTAGGGTTAAAGAC-1   15987.0
# TTTACTGCAGTATAAG-1   18628.0
# TTTACTGCATGCCTAA-1    4385.0
# TTTACTGGTTCGAATC-1    4090.0
# TTTACTGTCGTACGGC-1    6328.0
# TTTATGCTCAGGTAAA-1    4680.0
# TTTGCGCGTCTCCATC-1    5893.0
# TTTGCGCTCTGTCAAG-1   16873.0
# TTTGGTTTCACCTCGT-1   33347.0
# TTTGGTTTCATGCATG-1    5596.0
# TTTGTCACATCGGTTA-1   10405.0
#
# [931 rows x 1 columns]

# %%
sd.sf(d2)
# Out:
# Nr=11531
# gamma_c [0.33993718 0.33996944 0.3402598  4.38292661 6.16535087 7.50411367]
# array([[0.81680316],
#        [0.49577063],
#        [0.44998318],
#        [1.19324887],
#        [1.37084877],
#        [0.68741888],
#        [1.08363652],
#        [0.93361324],
#        [0.55647373],
#        [0.63660175],
#        [0.40575665],
#        [2.19493628],
#        [0.56887448],
#        [0.83536094],
#        [0.49620423],
#        [0.63434708],
#        [0.4185043 ],
#        [0.62151271],
#        [0.38329652],
#        [0.35571998],
#        [0.39023402],
#        [0.46090972],
#        [3.03012371],
#        [0.69609076],
#        [1.14798176],
#        [2.23604083],
#        [0.6863783 ],
#        [0.58535105],
#        [0.57234323],
#        [1.01608264],
#        [2.57129526],
#        [0.39214182],
#        [0.51025265],
#        [0.76685321],
#        [0.85495937],
#        [0.75835478],
#        [0.57711273],
#        [0.41035277],
#        [0.96197021],
#        [2.28971982],
#        [0.94800854],
#        [0.96205693],
#        [0.77205634],
#        [0.56341124],
#        [0.35832155],
#        [1.85309124],
#        [1.45921504],
#        [0.37878716],
#        [0.54468   ],
#        [1.49555016],
#        [1.89124751],
#        [1.77929366],
#        [0.53054482],
#        [2.03086448],
#        [0.44191834],
#        [1.55538607],
#        [0.6562869 ],
#        [0.66096973],
#        [3.13774157],
#        [0.69825876],
#        [0.70441574],
#        [0.81871098],
#        [0.86909455],
#        [0.79668444],
#        [0.6635713 ],
#        [0.61049944],
#        [0.59723151],
#        [0.63963693],
#        [1.23400664],
#        [1.32670891],
#        [0.77509147],
#        [0.34687468],
#        [0.46533239],
#        [1.25724733],
#        [0.38763246],
#        [0.4872722 ],
#        [0.39283559],
#        [0.36170357],
#        [0.60026664],
#        [0.5406909 ],
#        [1.22177935],
#        [0.85660702],
#        [0.60486275],
#        [1.27511132],
#        [3.25611258],
#        [0.71091968],
#        [2.33932281],
#        [0.85322499],
#        [0.60312837],
#        [1.3727566 ],
#        [1.81033897],
#        [0.59072757],
#        [0.85287815],
#        [0.93690854],
#        [0.94540697],
#        [1.16350436],
#        [0.56150341],
#        [0.78003442],
#        [0.84828204],
#        [0.41564259],
#        [0.47452456],
#        [0.49074095],
#        [0.94783509],
#        [2.11775661],
#        [0.74040401],
#        [0.57555181],
#        [0.80891174],
#        [1.52364707],
#        [0.60720414],
#        [0.73442042],
#        [0.43931678],
#        [0.38147545],
#        [0.83406019],
#        [0.59827209],
#        [0.49967298],
#        [1.58079469],
#        [1.1660192 ],
#        [0.61483538],
#        [1.99158096],
#        [1.67410398],
#        [0.61656976],
#        [0.62819004],
#        [0.7202853 ],
#        [1.78683817],
#        [0.60546976],
#        [0.71274078],
#        [0.45293161],
#        [1.330091  ],
#        [0.73710871],
#        [1.14347243],
#        [1.43900967],
#        [0.8403039 ],
#        [0.94618744],
#        [1.12274659],
#        [0.79113442],
#        [0.49655113],
#        [1.25507939],
#        [0.59133464],
#        [0.73277277],
#        [1.63846254],
#        [1.30390191],
#        [0.43263945],
#        [0.81905782],
#        [3.53404593],
#        [0.398559  ],
#        [2.7061429 ],
#        [0.82868361],
#        [0.84923595],
#        [1.20313489],
#        [0.39535043],
#        [0.70944548],
#        [0.86059612],
#        [0.60824478],
#        [0.47131598],
#        [1.98923957],
#        [0.67441112],
#        [1.48314941],
#        [0.60364866],
#        [0.34427312],
#        [1.71312737],
#        [0.69799858],
#        [1.10219431],
#        [0.41217384],
#        [0.7817688 ],
#        [0.46975505],
#        [0.73138529],
#        [4.12512064],
#        [0.63426036],
#        [1.96591222],
#        [0.50192767],
#        [0.44902927],
#        [0.55040342],
#        [0.7162962 ],
#        [0.63313299],
#        [0.75393212],
#        [0.49663782],
#        [0.39543715],
#        [0.42969102],
#        [0.59376276],
#        [1.59536338],
#        [0.72808999],
#        [2.09980583],
#        [1.45167053],
#        [0.49932611],
#        [0.39483011],
#        [1.31552219],
#        [0.39673793],
#        [0.99761158],
#        [0.36118326],
#        [0.7788204 ],
#        [0.66313767],
#        [0.46403161],
#        [0.65238458],
#        [0.72887045],
#        [0.3617903 ],
#        [0.48449722],
#        [4.87237549],
#        [0.46082303],
#        [0.92025852],
#        [1.46415806],
#        [0.6577611 ],
#        [0.83353984],
#        [0.43541446],
#        [0.47521833],
#        [0.62246662],
#        [0.57355732],
#        [0.46012926],
#        [0.44356599],
#        [0.47296363],
#        [2.0613029 ],
#        [0.76659304],
#        [3.22133851],
#        [0.78341645],
#        [1.56050253],
#        [0.85348517],
#        [0.82235318],
#        [0.68733221],
#        [1.0470413 ],
#        [1.52182591],
#        [1.85369837],
#        [0.66487205],
#        [0.89727807],
#        [1.24606061],
#        [0.48007455],
#        [1.61036575],
#        [0.75098372],
#        [0.61440176],
#        [0.51016593],
#        [0.80839145],
#        [0.39396292],
#        [0.53999716],
#        [0.38901997],
#        [0.58656508],
#        [1.00498271],
#        [1.86054909],
#        [0.59159476],
#        [1.12751615],
#        [0.57017529],
#        [0.59445649],
#        [0.47599879],
#        [4.63936234],
#        [0.9697749 ],
#        [1.09378254],
#        [1.16836071],
#        [0.44330585],
#        [0.38442388],
#        [1.26132309],
#        [0.60234791],
#        [0.81290084],
#        [0.74916261],
#        [0.49368939],
#        [1.15205753],
#        [2.66798663],
#        [1.33191204],
#        [1.48843932],
#        [1.11841071],
#        [0.38936684],
#        [0.80891174],
#        [1.24354577],
#        [0.37497154],
#        [0.50695735],
#        [0.94896245],
#        [0.61787051],
#        [1.16393805],
#        [2.56973433],
#        [0.88487732],
#        [2.5936687 ],
#        [0.80899847],
#        [0.5804081 ],
#        [0.36829421],
#        [2.07058167],
#        [1.66933441],
#        [1.68841255],
#        [0.50739092],
#        [1.54524004],
#        [0.36621293],
#        [0.42648244],
#        [0.58066821],
#        [2.92753553],
#        [1.44369245],
#        [0.40558323],
#        [0.3761856 ],
#        [1.72440076],
#        [0.508605  ],
#        [0.38563794],
#        [0.36187702],
#        [0.51146674],
#        [0.94896245],
#        [0.74742824],
#        [1.40198076],
#        [0.41876447],
#        [1.56978142],
#        [0.93803585],
#        [0.44096443],
#        [0.83050472],
#        [0.43810272],
#        [0.39647776],
#        [0.60989243],
#        [1.06577241],
#        [0.80050004],
#        [0.40723088],
#        [0.63374007],
#        [1.31257379],
#        [0.60113382],
#        [3.08388948],
#        [1.2593286 ],
#        [2.33498693],
#        [1.4335463 ],
#        [1.04513347],
#        [3.58061385],
#        [1.03394675],
#        [0.36153015],
#        [0.50314176],
#        [1.05918181],
#        [0.56228387],
#        [0.89528358],
#        [0.69348919],
#        [1.27805972],
#        [0.73953682],
#        [0.35892859],
#        [0.81142658],
#        [0.68247592],
#        [0.7695415 ],
#        [1.21137309],
#        [1.06030917],
#        [0.46064958],
#        [0.60330182],
#        [1.18475044],
#        [0.87152267],
#        [4.49341488],
#        [1.27381051],
#        [1.61183989],
#        [0.8895601 ],
#        [0.78090161],
#        [4.59721708],
#        [1.72526801],
#        [0.68160874],
#        [1.06143653],
#        [0.70667046],
#        [1.32497454],
#        [0.64397287],
#        [0.99691784],
#        [0.49507689],
#        [1.30754411],
#        [0.47200972],
#        [1.88248897],
#        [0.70961887],
#        [3.03541374],
#        [0.70268142],
#        [0.96960145],
#        [1.21510208],
#        [0.39691135],
#        [0.48441049],
#        [2.03684807],
#        [0.85322499],
#        [0.66227049],
#        [0.42891055],
#        [3.58503652],
#        [2.00987864],
#        [1.74980938],
#        [0.51242065],
#        [0.78619146],
#        [0.56254405],
#        [0.78150868],
#        [0.62307364],
#        [0.84446645],
#        [0.91609603],
#        [0.46255741],
#        [0.44755507],
#        [1.50283456],
#        [0.46984175],
#        [0.38260278],
#        [0.55022997],
#        [0.88062811],
#        [0.55465263],
#        [0.55239791],
#        [0.39786527],
#        [0.3650856 ],
#        [1.72604847],
#        [0.56367135],
#        [0.48033473],
#        [0.74101102],
#        [0.89129448],
#        [1.1670599 ],
#        [0.48683861],
#        [0.68464392],
#        [0.86276406],
#        [0.90092027],
#        [1.33243239],
#        [1.08485055],
#        [0.36482546],
#        [0.49559721],
#        [0.80726409],
#        [1.31127298],
#        [0.41442853],
#        [0.96665305],
#        [0.38000122],
#        [0.42284024],
#        [2.0017271 ],
#        [0.94410616],
#        [0.83761567],
#        [0.81879771],
#        [0.87308359],
#        [0.77170944],
#        [0.60885179],
#        [1.36460507],
#        [0.66374469],
#        [0.3775731 ],
#        [0.77500474],
#        [0.81333441],
#        [0.57702601],
#        [0.48094174],
#        [1.04435301],
#        [0.42856368],
#        [0.85799456],
#        [0.56549245],
#        [0.70606345],
#        [2.71758962],
#        [0.45865506],
#        [2.084023  ],
#        [0.37054887],
#        [0.76685321],
#        [0.49741828],
#        [0.77457118],
#        [1.05883503],
#        [1.72067189],
#        [0.43740898],
#        [0.46090972],
#        [0.78619146],
#        [1.88639128],
#        [1.5017072 ],
#        [0.67597204],
#        [0.50773782],
#        [0.49420971],
#        [1.16896772],
#        [0.46038944],
#        [1.55538607],
#        [2.41346741],
#        [3.49138045],
#        [0.48007455],
#        [0.63972366],
#        [0.9289304 ],
#        [0.50938547],
#        [1.49815178],
#        [0.36135671],
#        [0.57373071],
#        [0.60859162],
#        [1.23660827],
#        [0.56887448],
#        [0.3827762 ],
#        [1.2867316 ],
#        [0.59939945],
#        [1.4765588 ],
#        [2.71065211],
#        [0.49238861],
#        [1.09586382],
#        [1.21414816],
#        [0.46992847],
#        [0.85747421],
#        [0.46507224],
#        [0.60304165],
#        [0.49958625],
#        [1.35463238],
#        [0.53037137],
#        [0.40957227],
#        [0.74239856],
#        [0.36499888],
#        [0.80657035],
#        [0.41434181],
#        [0.44382617],
#        [0.37158951],
#        [0.79772508],
#        [1.06525218],
#        [0.61856431],
#        [0.7427454 ],
#        [0.71534234],
#        [0.51328784],
#        [0.46828082],
#        [1.25794101],
#        [0.47253004],
#        [1.04469979],
#        [0.52889717],
#        [0.48597142],
#        [0.36109656],
#        [0.64839548],
#        [0.61977834],
#        [1.5704751 ],
#        [1.4808948 ],
#        [1.10843801],
#        [0.43506756],
#        [0.69348919],
#        [1.58105481],
#        [0.56028932],
#        [0.74421966],
#        [0.71733683],
#        [2.16337061],
#        [1.03143191],
#        [0.79711801],
#        [2.36074233],
#        [0.78948677],
#        [1.91084588],
#        [1.23686838],
#        [0.56150341],
#        [1.36139643],
#        [0.48094174],
#        [1.46710646],
#        [0.83059144],
#        [0.90542966],
#        [0.94965619],
#        [1.83514047],
#        [0.42865038],
#        [0.51996517],
#        [0.79260868],
#        [0.66166347],
#        [1.58920634],
#        [0.41911134],
#        [1.36035585],
#        [0.40653715],
#        [0.42665586],
#        [0.58257604],
#        [0.60564321],
#        [1.53093147],
#        [4.02886295],
#        [1.12526143],
#        [1.16853404],
#        [0.69184154],
#        [0.57164949],
#        [0.52794325],
#        [0.98191553],
#        [0.63131195],
#        [0.48016128],
#        [0.65463924],
#        [0.84637421],
#        [0.59098774],
#        [0.76798058],
#        [0.92242652],
#        [1.59718454],
#        [0.50088704],
#        [0.77292353],
#        [0.37072232],
#        [0.95425224],
#        [2.77777243],
#        [0.43021134],
#        [0.62515491],
#        [0.71178687],
#        [0.45952225],
#        [0.61587602],
#        [0.84420627],
#        [0.62775648],
#        [0.53999716],
#        [0.6845572 ],
#        [0.67250329],
#        [0.82833678],
#        [1.92420065],
#        [0.5248214 ],
#        [1.39356899],
#        [0.41382149],
#        [0.87377733],
#        [0.84299219],
#        [0.57563853],
#        [1.22420752],
#        [1.22238636],
#        [0.73849618],
#        [0.49663782],
#        [1.02622879],
#        [0.56185025],
#        [0.60156745],
#        [1.59666419],
#        [1.38004088],
#        [1.21813715],
#        [0.65923536],
#        [0.82157272],
#        [3.30164003],
#        [0.52915734],
#        [0.42899728],
#        [0.7788204 ],
#        [1.15595984],
#        [0.73285949],
#        [0.34262547],
#        [1.04097092],
#        [0.43532774],
#        [0.82460785],
#        [0.48996049],
#        [0.59012055],
#        [0.71568918],
#        [0.65177751],
#        [0.4236207 ],
#        [2.27176905],
#        [0.93924993],
#        [0.73754227],
#        [2.88460994],
#        [0.44729492],
#        [1.16732001],
#        [0.68030798],
#        [0.77301025],
#        [0.4416582 ],
#        [0.39968637],
#        [0.59610415],
#        [3.18604398],
#        [0.71751028],
#        [0.4769527 ],
#        [1.67297661],
#        [0.71083295],
#        [0.7181173 ],
#        [2.64708734],
#        [0.51883781],
#        [1.04105771],
#        [0.55968231],
#        [0.47339723],
#        [0.7239275 ],
#        [1.17174268],
#        [0.54676121],
#        [1.04227173],
#        [0.85348517],
#        [0.65169084],
#        [1.95047641],
#        [0.73355323],
#        [0.60937208],
#        [1.19645751],
#        [1.89332879],
#        [0.88825935],
#        [0.36317781],
#        [0.65741426],
#        [1.01296079],
#        [0.78749228],
#        [0.60174084],
#        [0.87707263],
#        [0.47452456],
#        [2.03884268],
#        [2.28997993],
#        [2.23309255],
#        [0.66383141],
#        [1.67618525],
#        [1.70090008],
#        [0.48675191],
#        [0.58500415],
#        [1.10939193],
#        [0.66400486],
#        [0.70138061],
#        [1.82898355],
#        [1.26635277],
#        [0.50123394],
#        [2.18262219],
#        [0.8259086 ],
#        [0.37922075],
#        [0.86181015],
#        [0.57546508],
#        [0.4431324 ],
#        [0.57650572],
#        [0.60841823],
#        [0.78957349],
#        [1.76671946],
#        [0.41729024],
#        [0.66521895],
#        [1.52564156],
#        [0.85305154],
#        [0.89909917],
#        [0.37826684],
#        [0.61743695],
#        [1.54957592],
#        [0.50080031],
#        [1.26106286],
#        [0.86120313],
#        [0.70164078],
#        [1.02432096],
#        [0.40913868],
#        [0.34028408],
#        [2.33706808],
#        [0.76858759],
#        [0.90915853],
#        [0.43168554],
#        [0.74942273],
#        [0.54858232],
#        [1.13202548],
#        [1.36183   ],
#        [0.67024863],
#        [1.94588029],
#        [0.77179617],
#        [1.29349566],
#        [0.85504609],
#        [0.77023524],
#        [1.52295327],
#        [3.76974726],
#        [1.51575565],
#        [0.53045809],
#        [0.69903922],
#        [1.0192045 ],
#        [0.45163083],
#        [1.87251627],
#        [0.81862426],
#        [2.25555253],
#        [0.5830096 ],
#        [0.57190967],
#        [0.44920272],
#        [0.36725357],
#        [0.39552385],
#        [0.75505948],
#        [0.97653896],
#        [0.67527831],
#        [0.66730016],
#        [0.58118856],
#        [0.46047613],
#        [0.90118045],
#        [0.84151798],
#        [0.62957758],
#        [0.75670713],
#        [0.70641029],
#        [1.12396073],
#        [1.14607394],
#        [0.40341526],
#        [1.27372384],
#        [1.80765069],
#        [1.22715592],
#        [0.59671116],
#        [1.73289919],
#        [1.03845608],
#        [0.41234729],
#        [0.65715408],
#        [1.11381459],
#        [0.68403685],
#        [0.58951354],
#        [0.98425692],
#        [0.43376678],
#        [1.32965744],
#        [1.37076199],
#        [1.03438032],
#        [0.88166875],
#        [0.37956762],
#        [0.36335123],
#        [1.22620201],
#        [5.07460308],
#        [0.78332978],
#        [0.78697193],
#        [0.37930748],
#        [0.79651099],
#        [0.51250732],
#        [0.88539761],
#        [0.5476284 ],
#        [0.4078379 ],
#        [1.75960851],
#        [0.69479001],
#        [1.58651805],
#        [0.90482259],
#        [2.60051942],
#        [0.71438843],
#        [3.6753974 ],
#        [0.9929288 ],
#        [0.43446055],
#        [1.01773036],
#        [1.84389913],
#        [0.49776518],
#        [0.78879303],
#        [0.68386346],
#        [0.44504023],
#        [0.42969102],
#        [1.01365459],
#        [0.97610539],
#        [0.49845892],
#        [0.84880233],
#        [0.76685321],
#        [1.36720657],
#        [1.5195713 ],
#        [0.60009319],
#        [0.65411896],
#        [0.5977518 ],
#        [0.36638638],
#        [0.42743632],
#        [0.787579  ],
#        [3.05405807],
#        [0.78081495],
#        [1.63768208],
#        [0.95069677],
#        [0.65602672],
#        [3.50551558],
#        [0.91297418],
#        [1.00801778],
#        [0.60113382],
#        [2.03303242],
#        [1.62979066],
#        [0.64362597],
#        [0.40679729],
#        [0.90924525],
#        [2.27289629],
#        [2.37513781],
#        [0.94618744],
#        [0.65741426],
#        [0.49334252],
#        [0.68958688],
#        [0.34089109],
#        [0.58439714],
#        [0.53037137],
#        [0.50227457],
#        [0.6484822 ],
#        [0.56263071],
#        [0.48649174],
#        [1.83297253],
#        [1.41932452],
#        [1.31170666],
#        [0.73294622],
#        [1.70263433],
#        [0.50132066],
#        [3.04278469],
#        [0.41121992],
#        [0.43949023],
#        [0.61804396],
#        [1.14824188],
#        [1.27632546],
#        [1.14702785],
#        [0.69756502],
#        [0.39725822],
#        [0.49525034],
#        [1.18908644],
#        [2.2041285 ],
#        [0.60416901],
#        [0.74473995],
#        [1.38680494],
#        [0.74066418],
#        [1.09456313],
#        [0.41746369],
#        [1.56874073],
#        [0.48631832],
#        [1.11103964],
#        [0.33993718],
#        [1.06143653],
#        [0.9591952 ],
#        [1.22472775],
#        [1.01408815],
#        [0.3743645 ],
#        [0.63876975],
#        [0.49507689],
#        [0.43064493],
#        [0.49490345],
#        [0.67285019],
#        [1.27771294],
#        [5.48703718],
#        [0.50132066],
#        [0.3492161 ],
#        [1.36564565],
#        [0.60260803],
#        [2.72903657],
#        [0.35641375],
#        [0.65455252],
#        [0.63096505],
#        [0.50504953],
#        [0.34210515],
#        [2.4260416 ],
#        [3.85854721],
#        [0.3673403 ],
#        [0.40497619],
#        [5.83686018],
#        [4.55194998],
#        [0.46238396],
#        [1.83566082],
#        [0.57286352],
#        [4.05609226],
#        [2.38623762],
#        [0.3742778 ],
#        [0.61735022],
#        [3.35974145],
#        [1.18847942],
#        [0.62307364],
#        [0.59306902],
#        [2.59757113],
#        [0.49785188],
#        [0.77916723],
#        [0.98581785],
#        [0.67935407],
#        [1.43293929],
#        [0.3636114 ],
#        [0.59315574],
#        [0.5704354 ],
#        [0.46515894],
#        [7.50411367],
#        [0.39326918],
#        [0.67519158],
#        [0.56887448],
#        [0.72592199],
#        [0.56705338],
#        [0.80154067],
#        [1.55902827],
#        [0.65481269],
#        [0.55395889],
#        [0.53201902],
#        [0.93465382],
#        [0.82391411],
#        [0.80284148],
#        [0.74872899],
#        [0.3878926 ],
#        [0.70693064],
#        [0.36205044],
#        [0.81029928],
#        [1.47534478],
#        [0.61925805],
#        [0.61891115],
#        [0.44460663],
#        [1.52997756],
#        [1.01261389],
#        [0.81758362],
#        [0.5745979 ],
#        [0.99006706],
#        [0.41486213],
#        [0.62810332],
#        [0.65507287],
#        [0.68715876],
#        [0.70285481],
#        [0.44443318],
#        [0.90369529],
#        [1.06533885],
#        [6.06458378],
#        [0.38936684],
#        [0.66478533],
#        [0.66920799],
#        [1.18839264],
#        [1.88058114],
#        [0.36638638],
#        [0.75852823],
#        [2.40921807],
#        [0.79781175],
#        [0.3883262 ],
#        [1.41741669],
#        [1.38637137],
#        [1.61539543],
#        [0.38026136],
#        [0.35467938],
#        [0.54875576],
#        [0.40584338],
#        [0.51103312],
#        [1.46320415],
#        [2.89180756],
#        [0.48527768],
#        [0.90230775]])

# %%
sd.sf(d1)
# Out:
# Nr=7346
# gamma_c [0.30261216 0.30261216 0.3033101  3.06700076 5.10077825 7.93788576]
# array([[0.43166134],
#        [1.21643829],
#        [0.38837269],
#        ...,
#        [2.54014516],
#        [0.51674122],
#        [1.16961026]])

# %%
d2.X.sum()
# Out:
# 10735866.0

# %%
# plot_list = [['brain1k','brain2k'],['brain1k','brain9k'],['brain2k','brain9k']]
for pair in plot_list:
    d1,d2=pair
    sd.fig_xx_rank(M[d1],M_ml[d1],M[d2],M_ml[d2],gene_list[d1],gene_list[d2],[d1,d2],mean_fil=0)

# %%
## MSE
